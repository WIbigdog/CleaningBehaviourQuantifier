# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy import stats  # For mode calculation

# %%
df = pd.read_csv(r"C:\Users\raulo\Desktop\ze_vids\tracks_and_labels\Top+Front\Joinned\all_top+front_imputed.csv")
df_frame = pd.read_csv(r"C:\Users\raulo\Desktop\ze_vids\tracks_and_labels\Top+Front\Joinned\joinned_label+track_top+front.csv")

# %%
df["Behavior"].value_counts()
# Out:
# Background     419838
# interaction     73498
# posing            949
# jolts             153
# TS                 16
# Name: Behavior, dtype: int64

# %%
# Create a new DataFrame to store the results
new_df = pd.DataFrame()

# Add relevant data to the new DataFrame
new_df["Behavior"] = df['Behavior']

new_df['Client_Mouth_X_top'] = df['Client_Mouth']
new_df['Client_Mouth_Y_top'] = df['Client_Mouth.1']
new_df['Client_Mouth_Z_front']= df['Client_Mouth_Front.1']

new_df['Client_S1_X_top'] = df['Client_Spine_1']
new_df['Client_S1_Y_top'] = df['Client_Spine_1.1']
new_df['Client_S1_Z_front']= df['Client_Spine_head_Front.1']

new_df['Client_S2_X_top'] = df['Client_Spine_2']
new_df['Client_S2_Y_top'] = df['Client_Spine_2.1']
new_df['Client_S2_Z_front']= df['Client_Spine_mid_Front.1']

new_df['Client_Tail_X_top'] = df['Client_Tail']
new_df['Client_Tail_Y_top'] = df['Client_Tail.1']
new_df['Client_Tail_Z_front']= df['Client_Tail_Front.1']

new_df['Cleaner_Mouth_X_top'] = df['Cleaner_Mouth']
new_df['Cleaner_Mouth_Y_top'] = df['Cleaner_Mouth.1']
new_df['Cleaner_Mouth_Z_front']= df['Cleaner_Mouth_Front.1']

new_df['Cleaner_Spine1_X_top'] = df['Cleaner_Spine1']
new_df['Cleaner_Spine1_Y_top'] = df['Cleaner_Spine1.1']
new_df['Cleaner_Spine1_Z_front']= df['Cleaner_Spine1_Front.1']

new_df['Cleaner_Spine2_X_top'] = df['Cleaner_Spine2']
new_df['Cleaner_Spine2_Y_top'] = df['Cleaner_Spine2.1']
new_df['Cleaner_Spine2_Z_front']= df['Cleaner_Spine2_Front.1']

new_df['Cleaner_Tail_X_top'] = df['Cleaner_Tail']
new_df['Cleaner_Tail_Y_top'] = df['Cleaner_Tail.1']
new_df['Cleaner_Tail_Z_front']= df['Cleaner_Tail_Front.1']

new_df["Frame"] = df_frame['Frame'] #add column with frames

# %%
# Create a new column in new_df to store the centroid for each row
new_df['Client_Centroid_X'] = new_df[['Client_Mouth_X_top', 'Client_S1_X_top', 'Client_S2_X_top', 'Client_Tail_X_top']].mean(axis=1)
new_df['Client_Centroid_Y'] = new_df[['Client_Mouth_Y_top', 'Client_S1_Y_top', 'Client_S2_Y_top', 'Client_Tail_Y_top']].mean(axis=1)
new_df['Client_Centroid_Z'] = new_df[['Client_Mouth_Z_front', 'Client_S1_Z_front', 'Client_S2_Z_front', 'Client_Tail_Z_front']].mean(axis=1)

# %%
# Create a new column in new_df to store the centroid for each row
new_df['Cleaner_Centroid_X'] = new_df[['Cleaner_Mouth_X_top', 'Cleaner_Spine1_X_top', 'Cleaner_Spine2_X_top', 'Cleaner_Tail_X_top']].mean(axis=1)
new_df['Cleaner_Centroid_Y'] = new_df[['Cleaner_Mouth_Y_top', 'Cleaner_Spine1_Y_top', 'Cleaner_Spine2_Y_top', 'Cleaner_Tail_Y_top']].mean(axis=1)
new_df['Cleaner_Centroid_Z'] = new_df[['Cleaner_Mouth_Z_front', 'Cleaner_Spine1_Z_front', 'Cleaner_Spine2_Z_front', 'Cleaner_Tail_Z_front']].mean(axis=1)

# %%
# Calculate the Euclidean distance between the two centroids for each row
new_df['Distance'] = np.sqrt(
    (new_df['Client_Centroid_X'] - new_df['Cleaner_Centroid_X'])**2 +
    (new_df['Client_Centroid_Y'] - new_df['Cleaner_Centroid_Y'])**2 +
    (new_df['Client_Centroid_Z'] - new_df['Cleaner_Centroid_Z'])**2
)

# %%
# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot the first histogram (interaction)
ax1.hist(new_df[new_df['Behavior'] == 'interaction']['Distance'], bins=20, edgecolor='black', color='blue')
ax1.set_xlabel('Distance Between Centroids')
ax1.set_ylabel('Frequency')
ax1.set_title('Histogram of Distance Between Centroids (Interaction)')

# Plot the second histogram (non-interaction)
ax2.hist(new_df[new_df['Behavior'] == 'Background']['Distance'], bins=20, edgecolor='black', color='red')
ax2.set_xlabel('Distance Between Centroids')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of Distance Between Centroids (Background)')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
plt.show()

# %%
new_df
# Out:
#           Behavior  Client_Mouth_X_top  Client_Mouth_Y_top  \
# 0       Background            1308.093             419.526
# 1       Background            1301.067             414.470
# 2       Background            1269.530             414.470
# 3       Background            1264.340             406.180
# 4       Background            1259.199             406.180
# ...            ...                 ...                 ...
# 494449  Background             298.287             742.995
# 494450  Background             295.017             738.109
# 494451  Background             293.875             735.024
# 494452  Background             289.687             733.892
# 494453  Background             288.011             729.258
#
#         Client_Mouth_Z_front  Client_S1_X_top  Client_S1_Y_top  \
# 0                    892.211         1346.876          426.760
# 1                    892.209         1340.332          426.760
# 2                    893.869         1298.572          426.760
# 3                    898.790         1298.261          426.760
# 4                    898.790         1292.935          426.186
# ...                      ...              ...              ...
# 494449               812.957          260.575          796.450
# 494450               813.515          260.144          796.450
# 494451               818.079          260.144          796.215
# 494452               816.668          260.144          795.015
# 494453               811.736          259.939          780.600
#
#         Client_S1_Z_front  Client_S2_X_top  Client_S2_Y_top  \
# 0                 886.200         1403.251          427.585
# 1                 874.595         1388.009          420.569
# 2                 875.479         1364.604          420.569
# 3                 875.766         1348.578          428.476
# 4                 875.766         1340.558          428.476
# ...                   ...              ...              ...
# 494449            796.664          225.504          827.783
# 494450            800.570          226.543          827.935
# 494451            802.501          227.233          827.935
# 494452            802.372          227.266          827.935
# 494453            795.956          242.471          804.378
#
#         Client_S2_Z_front  ...  Cleaner_Tail_Y_top  Cleaner_Tail_Z_front  \
# 0                 916.081  ...             924.739               764.164
# 1                 867.733  ...             924.739               764.213
# 2                 859.737  ...             930.310               770.402
# 3                 868.607  ...             930.310               771.239
# 4                 868.607  ...             924.739               773.472
# ...                   ...  ...                 ...                   ...
# 494449            788.465  ...             321.148               236.557
# 494450            788.513  ...             311.338               251.281
# 494451            789.440  ...             306.764               268.449
# 494452            787.931  ...             300.703               268.449
# 494453            787.663  ...             289.748               268.449
#
#            Frame  Client_Centroid_X  Client_Centroid_Y  Client_Centroid_Z  \
# 0        25251.0         1372.62300          420.90175          908.40425
# 1        25252.0         1361.65450          417.70825          893.41550
# 2        25255.0         1331.62850          417.70825          892.05250
# 3        25256.0         1323.00275          418.13475          895.59625
# 4        25257.0         1318.38100          420.44175          895.59625
# ...          ...                ...                ...                ...
# 494449  168761.0          245.62700          798.31925          796.56775
# 494450  168762.0          244.94250          797.13625          797.71325
# 494451  168765.0          245.58275          796.33775          801.22075
# 494452  168766.0          244.51625          795.81475          800.45850
# 494453  168767.0          247.84725          785.32625          795.90275
#
#         Cleaner_Centroid_X  Cleaner_Centroid_Y  Cleaner_Centroid_Z    Distance
# 0               1241.82950           915.11000           774.03575  528.586443
# 1               1232.96375           912.63100           774.32400  525.064399
# 2               1222.79100           915.67100           777.93775  522.335790
# 3               1210.65650           915.71550           779.56200  523.136913
# 4               1189.16800           916.90925           780.31950  525.799113
# ...                    ...                 ...                 ...         ...
# 494449           832.83700           256.28975           266.78150  958.793530
# 494450           838.83125           244.95700           272.80350  965.989657
# 494451           840.66450           239.70475           276.40400  969.224023
# 494452           845.04000           232.80100           273.84250  977.209122
# 494453           847.81750           224.94700           268.72025  975.659056
#
# [494454 rows x 33 columns]

# %%
def detect_interactions(distances, min_consecutive=60, threshold=250):
    """
    Detect interactions in a sequence of distances.

    Parameters:
        distances (list or numpy array): A sequence of distances.
        min_consecutive (int): Minimum consecutive frames required for an interaction.
        threshold (float): Threshold value to determine an interaction.

    Returns:
        List of tuples where each tuple represents an interaction (start_frame, end_frame).
    """
    interactions = []
    current_start = None

    for i, distance in enumerate(distances):
        if distance < threshold:
            if current_start is None:
                current_start = i
        else:
            if current_start is not None:
                if i - current_start >= min_consecutive:
                    interactions.append((current_start, i - 1))
                current_start = None

    # Check if an interaction is ongoing at the end of the sequence
    if current_start is not None and len(distances) - current_start >= min_consecutive:
        interactions.append((current_start, len(distances) - 1))

    return interactions

# %%
total_frames = 0
correctly_detected_event = 0
total = 0
correctly_frame_count = 0

# Initialize the "Interaction_Predictions" column with a default value
new_df["Interaction_Predictions"] = "Background"

interactions = detect_interactions(new_df["Distance"])

for interaction in interactions:
    
    start_frame, end_frame = interaction
    
    if end_frame - start_frame + 1 >= 15:
        total += 1  # Increment the total count for eligible interactions
        total_frames += end_frame - start_frame + 1
        selected_data = new_df.loc[start_frame:end_frame, "Behavior"]
        mode_value = stats.mode(selected_data).mode[0]
        
        if mode_value == "interaction":
            correctly_detected_event +=1
            correctly_frame_count += end_frame - start_frame + 1
            
            
        # Store the prediction in the new column
        new_df.loc[start_frame:end_frame, "Interaction_Predictions"] = mode_value

        print(f"Interaction detected from frame {start_frame} to {end_frame} (Duration: {end_frame - start_frame + 1} frames) with a true Behavior of {mode_value}")
# Out:
# Interaction detected from frame 1583 to 1807 (Duration: 225 frames) with a true Behavior of interaction
# Interaction detected from frame 1999 to 2143 (Duration: 145 frames) with a true Behavior of interaction
# Interaction detected from frame 2473 to 2700 (Duration: 228 frames) with a true Behavior of interaction
# Interaction detected from frame 2818 to 2883 (Duration: 66 frames) with a true Behavior of interaction
# Interaction detected from frame 5322 to 5437 (Duration: 116 frames) with a true Behavior of interaction
# Interaction detected from frame 6838 to 6937 (Duration: 100 frames) with a true Behavior of interaction
# Interaction detected from frame 6991 to 7093 (Duration: 103 frames) with a true Behavior of interaction
# Interaction detected from frame 7994 to 8076 (Duration: 83 frames) with a true Behavior of interaction
# Interaction detected from frame 8697 to 8799 (Duration: 103 frames) with a true Behavior of interaction
# Interaction detected from frame 10298 to 10360 (Duration: 63 frames) with a true Behavior of interaction
# Interaction detected from frame 10853 to 10987 (Duration: 135 frames) with a true Behavior of interaction
# Interaction detected from frame 12508 to 12574 (Duration: 67 frames) with a true Behavior of interaction
# Interaction detected from frame 14108 to 14217 (Duration: 110 frames) with a true Behavior of interaction
# Interaction detected from frame 18722 to 18805 (Duration: 84 frames) with a true Behavior of interaction
# Interaction detected from frame 23194 to 23260 (Duration: 67 frames) with a true Behavior of interaction
# Interaction detected from frame 24789 to 24862 (Duration: 74 frames) with a true Behavior of Background
# Interaction detected from frame 26282 to 26346 (Duration: 65 frames) with a true Behavior of interaction
# Interaction detected from frame 27416 to 27517 (Duration: 102 frames) with a true Behavior of interaction
# Interaction detected from frame 27687 to 27833 (Duration: 147 frames) with a true Behavior of interaction
# Interaction detected from frame 28105 to 28187 (Duration: 83 frames) with a true Behavior of Background
# Interaction detected from frame 28488 to 29153 (Duration: 666 frames) with a true Behavior of interaction
# Interaction detected from frame 29183 to 29292 (Duration: 110 frames) with a true Behavior of interaction
# Interaction detected from frame 29965 to 30058 (Duration: 94 frames) with a true Behavior of Background
# Interaction detected from frame 30971 to 31192 (Duration: 222 frames) with a true Behavior of interaction
# Interaction detected from frame 32401 to 33039 (Duration: 639 frames) with a true Behavior of interaction
# Interaction detected from frame 33217 to 33288 (Duration: 72 frames) with a true Behavior of Background
# Interaction detected from frame 34670 to 34943 (Duration: 274 frames) with a true Behavior of interaction
# Interaction detected from frame 35006 to 35117 (Duration: 112 frames) with a true Behavior of interaction
# Interaction detected from frame 35218 to 35550 (Duration: 333 frames) with a true Behavior of interaction
# Interaction detected from frame 36552 to 36787 (Duration: 236 frames) with a true Behavior of interaction
# Interaction detected from frame 37185 to 37300 (Duration: 116 frames) with a true Behavior of Background
# Interaction detected from frame 37773 to 37875 (Duration: 103 frames) with a true Behavior of Background
# Interaction detected from frame 38487 to 38641 (Duration: 155 frames) with a true Behavior of interaction
# Interaction detected from frame 38681 to 38838 (Duration: 158 frames) with a true Behavior of interaction
# Interaction detected from frame 39252 to 39366 (Duration: 115 frames) with a true Behavior of Background
# Interaction detected from frame 39462 to 39592 (Duration: 131 frames) with a true Behavior of interaction
# Interaction detected from frame 40222 to 40282 (Duration: 61 frames) with a true Behavior of Background
# Interaction detected from frame 40415 to 40543 (Duration: 129 frames) with a true Behavior of interaction
# Interaction detected from frame 40595 to 40701 (Duration: 107 frames) with a true Behavior of interaction
# Interaction detected from frame 40841 to 41367 (Duration: 527 frames) with a true Behavior of interaction
# Interaction detected from frame 42157 to 42247 (Duration: 91 frames) with a true Behavior of interaction
# Interaction detected from frame 43777 to 43846 (Duration: 70 frames) with a true Behavior of Background
# Interaction detected from frame 44456 to 44557 (Duration: 102 frames) with a true Behavior of Background
# Interaction detected from frame 45423 to 45600 (Duration: 178 frames) with a true Behavior of interaction
# Interaction detected from frame 46139 to 46251 (Duration: 113 frames) with a true Behavior of interaction
# Interaction detected from frame 46862 to 46954 (Duration: 93 frames) with a true Behavior of Background
# Interaction detected from frame 47404 to 47584 (Duration: 181 frames) with a true Behavior of interaction
# Interaction detected from frame 47593 to 47657 (Duration: 65 frames) with a true Behavior of Background
# Interaction detected from frame 48554 to 48631 (Duration: 78 frames) with a true Behavior of Background
# Interaction detected from frame 48812 to 48945 (Duration: 134 frames) with a true Behavior of interaction
# Interaction detected from frame 51030 to 51157 (Duration: 128 frames) with a true Behavior of interaction
# Interaction detected from frame 51771 to 52152 (Duration: 382 frames) with a true Behavior of interaction
# Interaction detected from frame 52364 to 52504 (Duration: 141 frames) with a true Behavior of Background
# Interaction detected from frame 52678 to 52816 (Duration: 139 frames) with a true Behavior of Background
# Interaction detected from frame 52891 to 52988 (Duration: 98 frames) with a true Behavior of Background
# Interaction detected from frame 53612 to 53672 (Duration: 61 frames) with a true Behavior of Background
# Interaction detected from frame 54098 to 54212 (Duration: 115 frames) with a true Behavior of interaction
# Interaction detected from frame 54214 to 54289 (Duration: 76 frames) with a true Behavior of interaction
# Interaction detected from frame 54674 to 54780 (Duration: 107 frames) with a true Behavior of interaction
# Interaction detected from frame 55070 to 55174 (Duration: 105 frames) with a true Behavior of Background
# Interaction detected from frame 55655 to 55798 (Duration: 144 frames) with a true Behavior of interaction
# Interaction detected from frame 56017 to 56152 (Duration: 136 frames) with a true Behavior of interaction
# Interaction detected from frame 58229 to 58491 (Duration: 263 frames) with a true Behavior of interaction
# Interaction detected from frame 58665 to 58756 (Duration: 92 frames) with a true Behavior of Background
# Interaction detected from frame 59222 to 59393 (Duration: 172 frames) with a true Behavior of interaction
# Interaction detected from frame 60334 to 60475 (Duration: 142 frames) with a true Behavior of Background
# Interaction detected from frame 61139 to 61246 (Duration: 108 frames) with a true Behavior of Background
# Interaction detected from frame 61446 to 61509 (Duration: 64 frames) with a true Behavior of Background
# Interaction detected from frame 62599 to 62886 (Duration: 288 frames) with a true Behavior of interaction
# Interaction detected from frame 62888 to 63039 (Duration: 152 frames) with a true Behavior of Background
# Interaction detected from frame 63161 to 63281 (Duration: 121 frames) with a true Behavior of Background
# Interaction detected from frame 63401 to 63460 (Duration: 60 frames) with a true Behavior of Background
# Interaction detected from frame 64290 to 64361 (Duration: 72 frames) with a true Behavior of interaction
# Interaction detected from frame 64386 to 64609 (Duration: 224 frames) with a true Behavior of interaction
# Interaction detected from frame 66309 to 66497 (Duration: 189 frames) with a true Behavior of interaction
# Interaction detected from frame 67876 to 68129 (Duration: 254 frames) with a true Behavior of interaction
# Interaction detected from frame 69932 to 70019 (Duration: 88 frames) with a true Behavior of Background
# Interaction detected from frame 70973 to 71154 (Duration: 182 frames) with a true Behavior of Background
# Interaction detected from frame 71721 to 71841 (Duration: 121 frames) with a true Behavior of Background
# Interaction detected from frame 73095 to 73156 (Duration: 62 frames) with a true Behavior of Background
# Interaction detected from frame 77342 to 77428 (Duration: 87 frames) with a true Behavior of Background
# Interaction detected from frame 77672 to 77745 (Duration: 74 frames) with a true Behavior of interaction
# Interaction detected from frame 78366 to 78466 (Duration: 101 frames) with a true Behavior of Background
# Interaction detected from frame 78927 to 78999 (Duration: 73 frames) with a true Behavior of Background
# Interaction detected from frame 79942 to 80008 (Duration: 67 frames) with a true Behavior of interaction
# Interaction detected from frame 80085 to 80154 (Duration: 70 frames) with a true Behavior of interaction
# Interaction detected from frame 80944 to 81011 (Duration: 68 frames) with a true Behavior of interaction
# Interaction detected from frame 81113 to 81189 (Duration: 77 frames) with a true Behavior of interaction
# Interaction detected from frame 81675 to 81754 (Duration: 80 frames) with a true Behavior of interaction
# Interaction detected from frame 82048 to 82108 (Duration: 61 frames) with a true Behavior of Background
# Interaction detected from frame 83290 to 83370 (Duration: 81 frames) with a true Behavior of interaction
# Interaction detected from frame 83561 to 83650 (Duration: 90 frames) with a true Behavior of Background
# Interaction detected from frame 83840 to 83899 (Duration: 60 frames) with a true Behavior of Background
# Interaction detected from frame 84164 to 84247 (Duration: 84 frames) with a true Behavior of interaction
# Interaction detected from frame 85331 to 85399 (Duration: 69 frames) with a true Behavior of interaction
# Interaction detected from frame 85495 to 85564 (Duration: 70 frames) with a true Behavior of interaction
# Interaction detected from frame 85601 to 85765 (Duration: 165 frames) with a true Behavior of Background
# Interaction detected from frame 85953 to 86044 (Duration: 92 frames) with a true Behavior of interaction
# Interaction detected from frame 86237 to 86312 (Duration: 76 frames) with a true Behavior of interaction
# Interaction detected from frame 86530 to 86678 (Duration: 149 frames) with a true Behavior of interaction
# Interaction detected from frame 87120 to 87196 (Duration: 77 frames) with a true Behavior of Background
# Interaction detected from frame 87554 to 87624 (Duration: 71 frames) with a true Behavior of interaction
# Interaction detected from frame 87931 to 88072 (Duration: 142 frames) with a true Behavior of interaction
# Interaction detected from frame 89432 to 89553 (Duration: 122 frames) with a true Behavior of interaction
# Interaction detected from frame 89578 to 89701 (Duration: 124 frames) with a true Behavior of interaction
# Interaction detected from frame 90733 to 90872 (Duration: 140 frames) with a true Behavior of interaction
# Interaction detected from frame 92900 to 92995 (Duration: 96 frames) with a true Behavior of Background
# Interaction detected from frame 95832 to 95938 (Duration: 107 frames) with a true Behavior of Background
# Interaction detected from frame 104035 to 104237 (Duration: 203 frames) with a true Behavior of interaction
# Interaction detected from frame 108015 to 108090 (Duration: 76 frames) with a true Behavior of interaction
# Interaction detected from frame 109651 to 109711 (Duration: 61 frames) with a true Behavior of Background
# Interaction detected from frame 119393 to 119467 (Duration: 75 frames) with a true Behavior of interaction
# Interaction detected from frame 120622 to 120696 (Duration: 75 frames) with a true Behavior of interaction
# Interaction detected from frame 129725 to 129787 (Duration: 63 frames) with a true Behavior of Background
# Interaction detected from frame 130175 to 130244 (Duration: 70 frames) with a true Behavior of interaction
# Interaction detected from frame 130483 to 130562 (Duration: 80 frames) with a true Behavior of interaction
# Interaction detected from frame 130585 to 130671 (Duration: 87 frames) with a true Behavior of interaction
# Interaction detected from frame 130934 to 131039 (Duration: 106 frames) with a true Behavior of interaction
# Interaction detected from frame 133969 to 134079 (Duration: 111 frames) with a true Behavior of interaction
# Interaction detected from frame 134172 to 134401 (Duration: 230 frames) with a true Behavior of interaction
# Interaction detected from frame 137707 to 137827 (Duration: 121 frames) with a true Behavior of interaction
# Interaction detected from frame 137840 to 138029 (Duration: 190 frames) with a true Behavior of interaction
# Interaction detected from frame 138070 to 138178 (Duration: 109 frames) with a true Behavior of interaction
# Interaction detected from frame 138798 to 139039 (Duration: 242 frames) with a true Behavior of interaction
# Interaction detected from frame 139497 to 139575 (Duration: 79 frames) with a true Behavior of interaction
# Interaction detected from frame 140906 to 140975 (Duration: 70 frames) with a true Behavior of interaction
# Interaction detected from frame 141107 to 141221 (Duration: 115 frames) with a true Behavior of interaction
# Interaction detected from frame 141226 to 141392 (Duration: 167 frames) with a true Behavior of interaction
# Interaction detected from frame 144566 to 144651 (Duration: 86 frames) with a true Behavior of interaction
# Interaction detected from frame 148144 to 148203 (Duration: 60 frames) with a true Behavior of Background
# Interaction detected from frame 162499 to 162581 (Duration: 83 frames) with a true Behavior of interaction
# Interaction detected from frame 162752 to 162816 (Duration: 65 frames) with a true Behavior of interaction
# Interaction detected from frame 163804 to 163912 (Duration: 109 frames) with a true Behavior of interaction
# Interaction detected from frame 163977 to 164157 (Duration: 181 frames) with a true Behavior of interaction
# Interaction detected from frame 164325 to 164411 (Duration: 87 frames) with a true Behavior of interaction
# Interaction detected from frame 164842 to 164928 (Duration: 87 frames) with a true Behavior of interaction
# Interaction detected from frame 164930 to 165028 (Duration: 99 frames) with a true Behavior of interaction
# Interaction detected from frame 165608 to 165733 (Duration: 126 frames) with a true Behavior of interaction
# Interaction detected from frame 165744 to 165845 (Duration: 102 frames) with a true Behavior of interaction
# Interaction detected from frame 170408 to 170475 (Duration: 68 frames) with a true Behavior of interaction
# Interaction detected from frame 170869 to 170980 (Duration: 112 frames) with a true Behavior of Background
# Interaction detected from frame 171542 to 171604 (Duration: 63 frames) with a true Behavior of interaction
# Interaction detected from frame 171993 to 172089 (Duration: 97 frames) with a true Behavior of Background
# Interaction detected from frame 173120 to 173215 (Duration: 96 frames) with a true Behavior of interaction
# Interaction detected from frame 175418 to 175480 (Duration: 63 frames) with a true Behavior of interaction
# Interaction detected from frame 178179 to 178297 (Duration: 119 frames) with a true Behavior of interaction
# Interaction detected from frame 178427 to 178486 (Duration: 60 frames) with a true Behavior of interaction
# Interaction detected from frame 178488 to 178572 (Duration: 85 frames) with a true Behavior of interaction
# Interaction detected from frame 179098 to 179177 (Duration: 80 frames) with a true Behavior of Background
# Interaction detected from frame 179639 to 179812 (Duration: 174 frames) with a true Behavior of Background
# Interaction detected from frame 180409 to 180523 (Duration: 115 frames) with a true Behavior of Background
# Interaction detected from frame 180700 to 180877 (Duration: 178 frames) with a true Behavior of Background
# Interaction detected from frame 180883 to 180947 (Duration: 65 frames) with a true Behavior of Background
# Interaction detected from frame 183581 to 183743 (Duration: 163 frames) with a true Behavior of interaction
# Interaction detected from frame 183750 to 183817 (Duration: 68 frames) with a true Behavior of interaction
# Interaction detected from frame 183825 to 183934 (Duration: 110 frames) with a true Behavior of interaction
# Interaction detected from frame 184080 to 184339 (Duration: 260 frames) with a true Behavior of interaction
# Interaction detected from frame 184713 to 184880 (Duration: 168 frames) with a true Behavior of interaction
# Interaction detected from frame 185073 to 185206 (Duration: 134 frames) with a true Behavior of interaction
# Interaction detected from frame 185615 to 185674 (Duration: 60 frames) with a true Behavior of Background
# Interaction detected from frame 185812 to 185890 (Duration: 79 frames) with a true Behavior of Background
# Interaction detected from frame 186121 to 186424 (Duration: 304 frames) with a true Behavior of interaction
# Interaction detected from frame 186440 to 186508 (Duration: 69 frames) with a true Behavior of interaction
# Interaction detected from frame 186574 to 186787 (Duration: 214 frames) with a true Behavior of interaction
# Interaction detected from frame 186851 to 186924 (Duration: 74 frames) with a true Behavior of Background
# Interaction detected from frame 187543 to 187644 (Duration: 102 frames) with a true Behavior of Background
# Interaction detected from frame 188275 to 188360 (Duration: 86 frames) with a true Behavior of interaction
# Interaction detected from frame 189507 to 189657 (Duration: 151 frames) with a true Behavior of Background
# Interaction detected from frame 190281 to 190381 (Duration: 101 frames) with a true Behavior of Background
# Interaction detected from frame 190586 to 190645 (Duration: 60 frames) with a true Behavior of Background
# Interaction detected from frame 190963 to 191056 (Duration: 94 frames) with a true Behavior of Background
# Interaction detected from frame 192159 to 192290 (Duration: 132 frames) with a true Behavior of Background
# Interaction detected from frame 192296 to 192369 (Duration: 74 frames) with a true Behavior of interaction
# Interaction detected from frame 193033 to 193129 (Duration: 97 frames) with a true Behavior of interaction
# Interaction detected from frame 193203 to 193288 (Duration: 86 frames) with a true Behavior of interaction
# Interaction detected from frame 194175 to 194234 (Duration: 60 frames) with a true Behavior of Background
# Interaction detected from frame 195435 to 195558 (Duration: 124 frames) with a true Behavior of Background
# Interaction detected from frame 195674 to 195737 (Duration: 64 frames) with a true Behavior of Background
# Interaction detected from frame 195872 to 195982 (Duration: 111 frames) with a true Behavior of Background
# Interaction detected from frame 196670 to 196732 (Duration: 63 frames) with a true Behavior of Background
# Interaction detected from frame 196957 to 197034 (Duration: 78 frames) with a true Behavior of Background
# Interaction detected from frame 198923 to 198996 (Duration: 74 frames) with a true Behavior of Background
# Interaction detected from frame 199078 to 199191 (Duration: 114 frames) with a true Behavior of Background
# Interaction detected from frame 200668 to 200803 (Duration: 136 frames) with a true Behavior of Background
# Interaction detected from frame 200887 to 200977 (Duration: 91 frames) with a true Behavior of Background
# Interaction detected from frame 202403 to 202496 (Duration: 94 frames) with a true Behavior of Background
# Interaction detected from frame 203168 to 203248 (Duration: 81 frames) with a true Behavior of Background
# Interaction detected from frame 204060 to 204194 (Duration: 135 frames) with a true Behavior of interaction
# Interaction detected from frame 204197 to 204329 (Duration: 133 frames) with a true Behavior of interaction
# Interaction detected from frame 205076 to 205138 (Duration: 63 frames) with a true Behavior of interaction
# Interaction detected from frame 205317 to 205391 (Duration: 75 frames) with a true Behavior of interaction
# Interaction detected from frame 205676 to 205736 (Duration: 61 frames) with a true Behavior of interaction
# Interaction detected from frame 205953 to 206040 (Duration: 88 frames) with a true Behavior of Background
# Interaction detected from frame 206497 to 206633 (Duration: 137 frames) with a true Behavior of Background
# Interaction detected from frame 207857 to 207937 (Duration: 81 frames) with a true Behavior of interaction
# Interaction detected from frame 208001 to 208065 (Duration: 65 frames) with a true Behavior of interaction
# Interaction detected from frame 208120 to 208207 (Duration: 88 frames) with a true Behavior of interaction
# Interaction detected from frame 208222 to 208348 (Duration: 127 frames) with a true Behavior of interaction
# Interaction detected from frame 208465 to 208643 (Duration: 179 frames) with a true Behavior of interaction
# Interaction detected from frame 208672 to 208759 (Duration: 88 frames) with a true Behavior of interaction
# Interaction detected from frame 208996 to 209067 (Duration: 72 frames) with a true Behavior of interaction
# Interaction detected from frame 209138 to 209220 (Duration: 83 frames) with a true Behavior of interaction
# Interaction detected from frame 209889 to 210026 (Duration: 138 frames) with a true Behavior of interaction
# Interaction detected from frame 210113 to 210248 (Duration: 136 frames) with a true Behavior of interaction
# Interaction detected from frame 210612 to 210686 (Duration: 75 frames) with a true Behavior of Background
# Interaction detected from frame 211232 to 211349 (Duration: 118 frames) with a true Behavior of interaction
# Interaction detected from frame 211537 to 211664 (Duration: 128 frames) with a true Behavior of interaction
# Interaction detected from frame 211930 to 212094 (Duration: 165 frames) with a true Behavior of interaction
# Interaction detected from frame 212168 to 212228 (Duration: 61 frames) with a true Behavior of Background
# Interaction detected from frame 212671 to 212740 (Duration: 70 frames) with a true Behavior of interaction
# Interaction detected from frame 213163 to 213246 (Duration: 84 frames) with a true Behavior of Background
# Interaction detected from frame 213398 to 213464 (Duration: 67 frames) with a true Behavior of interaction
# Interaction detected from frame 214181 to 214240 (Duration: 60 frames) with a true Behavior of interaction
# Interaction detected from frame 214507 to 214624 (Duration: 118 frames) with a true Behavior of interaction
# Interaction detected from frame 214843 to 214909 (Duration: 67 frames) with a true Behavior of Background
# Interaction detected from frame 215438 to 215533 (Duration: 96 frames) with a true Behavior of interaction
# Interaction detected from frame 215626 to 215814 (Duration: 189 frames) with a true Behavior of interaction
# Interaction detected from frame 216078 to 216156 (Duration: 79 frames) with a true Behavior of Background
# Interaction detected from frame 216195 to 216381 (Duration: 187 frames) with a true Behavior of interaction
# Interaction detected from frame 216838 to 216940 (Duration: 103 frames) with a true Behavior of interaction
# Interaction detected from frame 218472 to 218547 (Duration: 76 frames) with a true Behavior of interaction
# Interaction detected from frame 218684 to 218762 (Duration: 79 frames) with a true Behavior of Background
# Interaction detected from frame 218806 to 218869 (Duration: 64 frames) with a true Behavior of Background
# Interaction detected from frame 219840 to 219969 (Duration: 130 frames) with a true Behavior of interaction
# Interaction detected from frame 220007 to 220122 (Duration: 116 frames) with a true Behavior of interaction
# Interaction detected from frame 220501 to 220568 (Duration: 68 frames) with a true Behavior of Background
# Interaction detected from frame 220627 to 220714 (Duration: 88 frames) with a true Behavior of Background
# Interaction detected from frame 221015 to 221108 (Duration: 94 frames) with a true Behavior of Background
# Interaction detected from frame 221606 to 221681 (Duration: 76 frames) with a true Behavior of interaction
# Interaction detected from frame 222487 to 222553 (Duration: 67 frames) with a true Behavior of interaction
# Interaction detected from frame 223881 to 223952 (Duration: 72 frames) with a true Behavior of Background
# Interaction detected from frame 224559 to 224664 (Duration: 106 frames) with a true Behavior of Background
# Interaction detected from frame 224908 to 225006 (Duration: 99 frames) with a true Behavior of Background
# Interaction detected from frame 225236 to 225318 (Duration: 83 frames) with a true Behavior of Background
# Interaction detected from frame 226264 to 226386 (Duration: 123 frames) with a true Behavior of Background
# Interaction detected from frame 227423 to 227663 (Duration: 241 frames) with a true Behavior of interaction
# Interaction detected from frame 227678 to 227748 (Duration: 71 frames) with a true Behavior of interaction
# Interaction detected from frame 227874 to 227953 (Duration: 80 frames) with a true Behavior of interaction
# Interaction detected from frame 230829 to 230898 (Duration: 70 frames) with a true Behavior of Background
# Interaction detected from frame 231808 to 231888 (Duration: 81 frames) with a true Behavior of Background
# Interaction detected from frame 232878 to 232953 (Duration: 76 frames) with a true Behavior of Background
# Interaction detected from frame 238052 to 238123 (Duration: 72 frames) with a true Behavior of Background
# Interaction detected from frame 243226 to 243288 (Duration: 63 frames) with a true Behavior of Background
# Interaction detected from frame 251543 to 251633 (Duration: 91 frames) with a true Behavior of Background
# Interaction detected from frame 251950 to 252012 (Duration: 63 frames) with a true Behavior of Background
# Interaction detected from frame 256163 to 256254 (Duration: 92 frames) with a true Behavior of interaction
# Interaction detected from frame 257111 to 257190 (Duration: 80 frames) with a true Behavior of interaction
# Interaction detected from frame 261803 to 261868 (Duration: 66 frames) with a true Behavior of Background
# Interaction detected from frame 263016 to 263080 (Duration: 65 frames) with a true Behavior of interaction
# Interaction detected from frame 264402 to 264714 (Duration: 313 frames) with a true Behavior of interaction
# Interaction detected from frame 275388 to 275459 (Duration: 72 frames) with a true Behavior of Background
# Interaction detected from frame 275937 to 276172 (Duration: 236 frames) with a true Behavior of interaction
# Interaction detected from frame 277861 to 277995 (Duration: 135 frames) with a true Behavior of interaction
# Interaction detected from frame 278328 to 278415 (Duration: 88 frames) with a true Behavior of interaction
# Interaction detected from frame 278977 to 279044 (Duration: 68 frames) with a true Behavior of interaction
# Interaction detected from frame 279080 to 279210 (Duration: 131 frames) with a true Behavior of interaction
# Interaction detected from frame 279368 to 279729 (Duration: 362 frames) with a true Behavior of interaction
# Interaction detected from frame 280425 to 280485 (Duration: 61 frames) with a true Behavior of interaction
# Interaction detected from frame 283043 to 283150 (Duration: 108 frames) with a true Behavior of interaction
# Interaction detected from frame 283192 to 283259 (Duration: 68 frames) with a true Behavior of interaction
# Interaction detected from frame 284280 to 284343 (Duration: 64 frames) with a true Behavior of interaction
# Interaction detected from frame 284401 to 284469 (Duration: 69 frames) with a true Behavior of interaction
# Interaction detected from frame 284541 to 284667 (Duration: 127 frames) with a true Behavior of interaction
# Interaction detected from frame 290698 to 290785 (Duration: 88 frames) with a true Behavior of Background
# Interaction detected from frame 315417 to 315489 (Duration: 73 frames) with a true Behavior of interaction
# Interaction detected from frame 315700 to 315759 (Duration: 60 frames) with a true Behavior of Background
# Interaction detected from frame 316470 to 316536 (Duration: 67 frames) with a true Behavior of Background
# Interaction detected from frame 318141 to 318226 (Duration: 86 frames) with a true Behavior of interaction
# Interaction detected from frame 323011 to 323076 (Duration: 66 frames) with a true Behavior of interaction
# Interaction detected from frame 332563 to 332639 (Duration: 77 frames) with a true Behavior of Background
# Interaction detected from frame 332790 to 332853 (Duration: 64 frames) with a true Behavior of Background
# Interaction detected from frame 335440 to 335528 (Duration: 89 frames) with a true Behavior of Background
# Interaction detected from frame 335627 to 335739 (Duration: 113 frames) with a true Behavior of Background
# Interaction detected from frame 335772 to 335885 (Duration: 114 frames) with a true Behavior of Background
# Interaction detected from frame 335972 to 336129 (Duration: 158 frames) with a true Behavior of Background
# Interaction detected from frame 336408 to 336489 (Duration: 82 frames) with a true Behavior of Background
# Interaction detected from frame 336491 to 336560 (Duration: 70 frames) with a true Behavior of Background
# Interaction detected from frame 336562 to 336737 (Duration: 176 frames) with a true Behavior of Background
# Interaction detected from frame 336815 to 337041 (Duration: 227 frames) with a true Behavior of Background
# Interaction detected from frame 337107 to 337175 (Duration: 69 frames) with a true Behavior of Background
# Interaction detected from frame 337192 to 337337 (Duration: 146 frames) with a true Behavior of Background
# Interaction detected from frame 337438 to 337725 (Duration: 288 frames) with a true Behavior of Background
# Interaction detected from frame 337733 to 338098 (Duration: 366 frames) with a true Behavior of Background
# Interaction detected from frame 338127 to 338352 (Duration: 226 frames) with a true Behavior of Background
# Interaction detected from frame 338400 to 338774 (Duration: 375 frames) with a true Behavior of Background
# Interaction detected from frame 339213 to 339283 (Duration: 71 frames) with a true Behavior of Background
# Interaction detected from frame 339776 to 339869 (Duration: 94 frames) with a true Behavior of interaction
# Interaction detected from frame 340444 to 340504 (Duration: 61 frames) with a true Behavior of interaction
# Interaction detected from frame 340538 to 340676 (Duration: 139 frames) with a true Behavior of Background
# Interaction detected from frame 340757 to 341192 (Duration: 436 frames) with a true Behavior of interaction
# Interaction detected from frame 343044 to 343154 (Duration: 111 frames) with a true Behavior of Background
# Interaction detected from frame 348327 to 348438 (Duration: 112 frames) with a true Behavior of interaction
# Interaction detected from frame 348488 to 348627 (Duration: 140 frames) with a true Behavior of interaction
# Interaction detected from frame 348681 to 348765 (Duration: 85 frames) with a true Behavior of Background
# Interaction detected from frame 348995 to 349141 (Duration: 147 frames) with a true Behavior of Background
# Interaction detected from frame 357321 to 357430 (Duration: 110 frames) with a true Behavior of interaction
# Interaction detected from frame 357435 to 357503 (Duration: 69 frames) with a true Behavior of interaction
# Interaction detected from frame 357516 to 357579 (Duration: 64 frames) with a true Behavior of interaction
# Interaction detected from frame 360293 to 360469 (Duration: 177 frames) with a true Behavior of interaction
# Interaction detected from frame 360674 to 360770 (Duration: 97 frames) with a true Behavior of interaction
# Interaction detected from frame 367102 to 367364 (Duration: 263 frames) with a true Behavior of interaction
# Interaction detected from frame 367512 to 367826 (Duration: 315 frames) with a true Behavior of interaction
# Interaction detected from frame 367846 to 367962 (Duration: 117 frames) with a true Behavior of interaction
# Interaction detected from frame 368020 to 368126 (Duration: 107 frames) with a true Behavior of interaction
# Interaction detected from frame 368128 to 368244 (Duration: 117 frames) with a true Behavior of interaction
# Interaction detected from frame 368459 to 368734 (Duration: 276 frames) with a true Behavior of interaction
# Interaction detected from frame 370124 to 370205 (Duration: 82 frames) with a true Behavior of interaction
# Interaction detected from frame 370225 to 370315 (Duration: 91 frames) with a true Behavior of interaction
# Interaction detected from frame 374153 to 374696 (Duration: 544 frames) with a true Behavior of interaction
# Interaction detected from frame 375209 to 375680 (Duration: 472 frames) with a true Behavior of interaction
# Interaction detected from frame 375689 to 375761 (Duration: 73 frames) with a true Behavior of interaction
# Interaction detected from frame 379574 to 379702 (Duration: 129 frames) with a true Behavior of interaction
# Interaction detected from frame 379713 to 380165 (Duration: 453 frames) with a true Behavior of interaction
# Interaction detected from frame 380320 to 380455 (Duration: 136 frames) with a true Behavior of interaction
# Interaction detected from frame 380461 to 380660 (Duration: 200 frames) with a true Behavior of interaction
# Interaction detected from frame 380685 to 380786 (Duration: 102 frames) with a true Behavior of interaction
# Interaction detected from frame 384976 to 385094 (Duration: 119 frames) with a true Behavior of interaction
# Interaction detected from frame 385126 to 385395 (Duration: 270 frames) with a true Behavior of interaction
# Interaction detected from frame 390353 to 390479 (Duration: 127 frames) with a true Behavior of interaction
# Interaction detected from frame 390922 to 391130 (Duration: 209 frames) with a true Behavior of interaction
# Interaction detected from frame 393813 to 394174 (Duration: 362 frames) with a true Behavior of interaction
# Interaction detected from frame 395296 to 395365 (Duration: 70 frames) with a true Behavior of interaction
# Interaction detected from frame 395416 to 395501 (Duration: 86 frames) with a true Behavior of interaction
# Interaction detected from frame 396922 to 397073 (Duration: 152 frames) with a true Behavior of interaction
# Interaction detected from frame 398334 to 398492 (Duration: 159 frames) with a true Behavior of interaction
# Interaction detected from frame 398494 to 398680 (Duration: 187 frames) with a true Behavior of interaction
# Interaction detected from frame 400212 to 400342 (Duration: 131 frames) with a true Behavior of interaction
# Interaction detected from frame 404554 to 405054 (Duration: 501 frames) with a true Behavior of Background
# Interaction detected from frame 413398 to 413458 (Duration: 61 frames) with a true Behavior of Background
# Interaction detected from frame 421087 to 421232 (Duration: 146 frames) with a true Behavior of Background
# Interaction detected from frame 421238 to 421318 (Duration: 81 frames) with a true Behavior of Background
# Interaction detected from frame 421695 to 421769 (Duration: 75 frames) with a true Behavior of Background
# Interaction detected from frame 423737 to 423878 (Duration: 142 frames) with a true Behavior of Background
# Interaction detected from frame 431846 to 432097 (Duration: 252 frames) with a true Behavior of interaction
# Interaction detected from frame 433028 to 433098 (Duration: 71 frames) with a true Behavior of Background
# Interaction detected from frame 433141 to 433207 (Duration: 67 frames) with a true Behavior of Background
# Interaction detected from frame 433230 to 433321 (Duration: 92 frames) with a true Behavior of Background
# Interaction detected from frame 433757 to 433819 (Duration: 63 frames) with a true Behavior of Background
# Interaction detected from frame 434240 to 434321 (Duration: 82 frames) with a true Behavior of Background
# Interaction detected from frame 436375 to 436532 (Duration: 158 frames) with a true Behavior of interaction
# Interaction detected from frame 436825 to 436913 (Duration: 89 frames) with a true Behavior of Background
# Interaction detected from frame 436965 to 437038 (Duration: 74 frames) with a true Behavior of Background
# Interaction detected from frame 437310 to 437459 (Duration: 150 frames) with a true Behavior of interaction
# Interaction detected from frame 437879 to 438047 (Duration: 169 frames) with a true Behavior of interaction
# Interaction detected from frame 438079 to 438143 (Duration: 65 frames) with a true Behavior of interaction
# Interaction detected from frame 439044 to 439513 (Duration: 470 frames) with a true Behavior of interaction
# Interaction detected from frame 440006 to 440079 (Duration: 74 frames) with a true Behavior of interaction
# Interaction detected from frame 440661 to 440770 (Duration: 110 frames) with a true Behavior of Background
# Interaction detected from frame 441601 to 441661 (Duration: 61 frames) with a true Behavior of interaction
# Interaction detected from frame 442394 to 442903 (Duration: 510 frames) with a true Behavior of interaction
# Interaction detected from frame 443463 to 443600 (Duration: 138 frames) with a true Behavior of interaction
# Interaction detected from frame 443639 to 443730 (Duration: 92 frames) with a true Behavior of interaction
# Interaction detected from frame 444851 to 444998 (Duration: 148 frames) with a true Behavior of interaction
# Interaction detected from frame 445766 to 445849 (Duration: 84 frames) with a true Behavior of Background
# Interaction detected from frame 446196 to 446319 (Duration: 124 frames) with a true Behavior of Background
# Interaction detected from frame 446649 to 446791 (Duration: 143 frames) with a true Behavior of interaction
# Interaction detected from frame 447142 to 447272 (Duration: 131 frames) with a true Behavior of interaction
# Interaction detected from frame 447387 to 447458 (Duration: 72 frames) with a true Behavior of Background
# Interaction detected from frame 447713 to 447788 (Duration: 76 frames) with a true Behavior of interaction
# Interaction detected from frame 448936 to 449012 (Duration: 77 frames) with a true Behavior of interaction
# Interaction detected from frame 449016 to 449276 (Duration: 261 frames) with a true Behavior of interaction
# Interaction detected from frame 450363 to 450471 (Duration: 109 frames) with a true Behavior of Background
# Interaction detected from frame 450630 to 450712 (Duration: 83 frames) with a true Behavior of interaction
# Interaction detected from frame 450749 to 450827 (Duration: 79 frames) with a true Behavior of interaction
# Interaction detected from frame 451346 to 451466 (Duration: 121 frames) with a true Behavior of interaction
# Interaction detected from frame 451695 to 451761 (Duration: 67 frames) with a true Behavior of interaction
# Interaction detected from frame 451821 to 451891 (Duration: 71 frames) with a true Behavior of interaction
# Interaction detected from frame 451894 to 452001 (Duration: 108 frames) with a true Behavior of interaction
# Interaction detected from frame 452580 to 452719 (Duration: 140 frames) with a true Behavior of interaction
# Interaction detected from frame 453017 to 453178 (Duration: 162 frames) with a true Behavior of interaction
# Interaction detected from frame 453184 to 453336 (Duration: 153 frames) with a true Behavior of interaction
# Interaction detected from frame 454852 to 454919 (Duration: 68 frames) with a true Behavior of Background
# Interaction detected from frame 455705 to 455777 (Duration: 73 frames) with a true Behavior of interaction
# Interaction detected from frame 456120 to 456211 (Duration: 92 frames) with a true Behavior of interaction
# Interaction detected from frame 456543 to 456681 (Duration: 139 frames) with a true Behavior of interaction
# Interaction detected from frame 457494 to 457561 (Duration: 68 frames) with a true Behavior of interaction
# Interaction detected from frame 457584 to 457643 (Duration: 60 frames) with a true Behavior of interaction
# Interaction detected from frame 458018 to 458204 (Duration: 187 frames) with a true Behavior of interaction
# Interaction detected from frame 458698 to 458842 (Duration: 145 frames) with a true Behavior of interaction
# Interaction detected from frame 462612 to 462769 (Duration: 158 frames) with a true Behavior of Background
# Interaction detected from frame 463041 to 463117 (Duration: 77 frames) with a true Behavior of Background
# Interaction detected from frame 466394 to 466468 (Duration: 75 frames) with a true Behavior of Background
# Interaction detected from frame 468959 to 469042 (Duration: 84 frames) with a true Behavior of interaction
# Interaction detected from frame 469361 to 469446 (Duration: 86 frames) with a true Behavior of Background
# Interaction detected from frame 469699 to 469788 (Duration: 90 frames) with a true Behavior of interaction
# Interaction detected from frame 469794 to 469882 (Duration: 89 frames) with a true Behavior of interaction
# Interaction detected from frame 469951 to 470020 (Duration: 70 frames) with a true Behavior of Background
# Interaction detected from frame 470843 to 470908 (Duration: 66 frames) with a true Behavior of Background
# Interaction detected from frame 472827 to 472901 (Duration: 75 frames) with a true Behavior of Background
# Interaction detected from frame 473609 to 473683 (Duration: 75 frames) with a true Behavior of Background
# Interaction detected from frame 478165 to 478243 (Duration: 79 frames) with a true Behavior of Background
# Interaction detected from frame 479555 to 479639 (Duration: 85 frames) with a true Behavior of Background
# Interaction detected from frame 479664 to 479740 (Duration: 77 frames) with a true Behavior of Background
# Interaction detected from frame 481773 to 481832 (Duration: 60 frames) with a true Behavior of Background
# Interaction detected from frame 483366 to 483442 (Duration: 77 frames) with a true Behavior of Background
# Interaction detected from frame 485229 to 485365 (Duration: 137 frames) with a true Behavior of Background
# Interaction detected from frame 488820 to 488983 (Duration: 164 frames) with a true Behavior of interaction
# Interaction detected from frame 489202 to 489278 (Duration: 77 frames) with a true Behavior of Background
# Interaction detected from frame 489503 to 489700 (Duration: 198 frames) with a true Behavior of interaction
# Interaction detected from frame 489730 to 489916 (Duration: 187 frames) with a true Behavior of interaction
# Interaction detected from frame 490215 to 490276 (Duration: 62 frames) with a true Behavior of Background
# Interaction detected from frame 490452 to 490569 (Duration: 118 frames) with a true Behavior of Background
# Interaction detected from frame 491161 to 491264 (Duration: 104 frames) with a true Behavior of Background
# C:\Users\raulo\AppData\Local\Temp\ipykernel_8004\3175785233.py:19: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_value = stats.mode(selected_data).mode[0]
# C:\Users\raulo\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:110: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "
# C:\Users\raulo\AppData\Local\Temp\ipykernel_8004\3175785233.py:19: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   mode_value = stats.mode(selected_data).mode[0]

# %%
print(f"There was {correctly_frame_count} frames correclty classified, and a total of {total_frames} frames classified as interaction.")
print(f"Making this a {correctly_frame_count/total_frames *100} % accuracy.")
print(f"There was a total of {correctly_detected_event} events detected correctly. With a total of {total} events detected.")
# Out:
# There was 34547 frames correclty classified, and a total of 50472 frames classified as interaction.
# Making this a 68.44785227452846 % accuracy.
# There was a total of 246 events detected correctly. With a total of 403 events detected.

# %%
df["Behavior"].value_counts()
# Out:
# Background     419838
# interaction     73498
# posing            949
# jolts             153
# TS                 16
# Name: Behavior, dtype: int64

# %%
new_df["Interaction_Predictions"].value_counts()
# Out:
# Background     459907
# interaction     34547
# Name: Interaction_Predictions, dtype: int64
