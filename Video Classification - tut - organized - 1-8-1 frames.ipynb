# %% [markdown]
# **Table of Contents:**
# <br> **1- Video classification**
# + Imports
# + Classes
# + Functions
# + Model Structure
# + Model Stucture
# + Checking Frames
#
# <br> **2- Data with everything**
# <br> **3- Data joined interactions and jolt+run**
# <br> **4- Int and background**
# <br> **5- Background and Interactions(jolt+chase+TS+Ints)**
# <br> **6- Training with one video**
# <br> **7- Background and Interactions(jolt+chase+TS+Ints) lr=0.001**
# <br> **8- Background and Interactions(jolt+chase+TS+Ints) lr=0.01**

# %% [markdown]
# # Video Classification
# https://www.tensorflow.org/tutorials/video/video_classification

# %% [markdown]
# ## Imports

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.11.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\users\public\new\envs\tensorflowraul\lib\site-packages
# Requires: tensorflow-intel
# Required-by:
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\bee team\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\public\new\envs\tensorflowraul\lib\site-packages)

# %%
import tqdm
import random
import pathlib
import itertools
import collections

import cv2
import einops
import numpy as np
import remotezip as rz
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers

from pathlib import Path
import os

# %%
# Set the seed for Python's random number generator
random.seed(1999)

# Set the seed for NumPy's random number generator
np.random.seed(1999)

# Set the seed for TensorFlow's random number generator
tf.random.set_seed(1999)

# %% [markdown]
# ## Classes:

# %%
class FrameGenerator:
  def __init__(self, path, n_frames, training = False):
    """ Returns a set of frames with their associated label. 

      Args:
        path: Video file paths.
        n_frames: Number of frames. 
        training: Boolean to determine if training dataset is being created.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.mp4'))
    classes = [p.parent.name for p in video_paths] 
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path, self.n_frames) 
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %%
class Conv2Plus1D(keras.layers.Layer):
  def __init__(self, filters, kernel_size, padding):
    """
      A sequence of convolutional layers that first apply the convolution operation over the
      spatial dimensions, and then the temporal dimension. 
    """
    super().__init__()
    self.seq = keras.Sequential([  
        # Spatial decomposition
        layers.Conv3D(filters=filters,
                      kernel_size=(1, kernel_size[1], kernel_size[2]),
                      padding=padding),
        # Temporal decomposition
        layers.Conv3D(filters=filters, 
                      kernel_size=(kernel_size[0], 1, 1),
                      padding=padding)
        ])

  def call(self, x):
    return self.seq(x)

# %%
class ResidualMain(keras.layers.Layer):
  """
    Residual block of the model with convolution, layer normalization, and the
    activation function, ReLU.
  """
  def __init__(self, filters, kernel_size):
    super().__init__()
    self.seq = keras.Sequential([
        Conv2Plus1D(filters=filters,
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization(),
        layers.ReLU(),
        Conv2Plus1D(filters=filters, 
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %%
class Project(keras.layers.Layer):
  """
    Project certain dimensions of the tensor as the data is passed through different 
    sized filters and downsampled. 
  """
  def __init__(self, units):
    super().__init__()
    self.seq = keras.Sequential([
        layers.Dense(units),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %%
class ResizeVideo(keras.layers.Layer):
  def __init__(self, height, width):
    super().__init__()
    self.height = height
    self.width = width
    self.resizing_layer = layers.Resizing(self.height, self.width)

  def call(self, video):
    """
      Use the einops library to resize the tensor.  

      Args:
        video: Tensor representation of the video, in the form of a set of frames.

      Return:
        A downsampled size of the video according to the new height and width it should be resized to.
    """
    # b stands for batch size, t stands for time, h stands for height, 
    # w stands for width, and c stands for the number of channels.
    old_shape = einops.parse_shape(video, 'b t h w c')
    images = einops.rearrange(video, 'b t h w c -> (b t) h w c')
    images = self.resizing_layer(images)
    videos = einops.rearrange(
        images, '(b t) h w c -> b t h w c',
        t = old_shape['t'])
    return videos

# %% [markdown]
# ## Functions

# %%
# def frames_from_video_file(video_path, n_frames, output_size=(224, 224)):
#     """
#     Creates frames from a video file.

#     Args:
#       video_path: File path to the video.
#       n_frames: Number of frames to be created.
#       output_size: Pixel size of the output frame image.

#     Return:
#       A NumPy array of frames in the shape of (n_frames, height, width, channels).
#     """
#     # Read the video
#     result = []
#     src = cv2.VideoCapture(str(video_path))

#     video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

#     # Calculate the middle frame
#     middle_frame_idx = video_length // 2

#     # Set the frame pointer to the middle frame
#     src.set(cv2.CAP_PROP_POS_FRAMES, middle_frame_idx)

#     # Read the middle frame
#     ret, frame = src.read()
#     if ret:
#         middle_frame = format_frames(frame, output_size)
#     else:
#         # Return an empty array if unable to read the middle frame
#         src.release()
#         return np.empty((0, output_size[0], output_size[1], 3))

#     # Add the middle frame multiple times to the result
#     for _ in range(n_frames):
#         result.append(middle_frame)

#     src.release()
#     result = np.array(result)

#     return result

# %%
def frames_from_video_file(video_path, n_frames, output_size=(224, 224)):
    """
    Creates frames from a video file.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created.
      output_size: Pixel size of the output frame image.

    Return:
      A NumPy array of frames in the shape of (n_frames, height, width, channels).
    """
    # Read the video
    result = []
    src = cv2.VideoCapture(str(video_path))

    video_length = int(src.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the frame ranges for each fourth of the video
    first_part_end = video_length // 4
    second_part_start = first_part_end + 1
    second_part_end = 3 * first_part_end
    last_part_start = second_part_end + 1
    last_part_end = video_length-1

    if video_length < 17:
        for _ in range(10):
            src.set(cv2.CAP_PROP_POS_FRAMES, random.randint(0, video_length-1))
            ret, frame = src.read()
            if ret:
                result.append(format_frames(frame, output_size))
            else:
                result.append(np.zeros_like(result[0]))        
    
    else:    
        # Select 1 random frame from the first quarter
        src.set(cv2.CAP_PROP_POS_FRAMES, random.randint(0, first_part_end))
        ret, frame = src.read()
        if ret:
            result.append(format_frames(frame, output_size))
            
        # Select 8 random frames from the second and third quarter   
        frame_indices = random.sample(range(second_part_start, second_part_end + 1), min(8, second_part_end - second_part_start + 1))
        for index in frame_indices:
            src.set(cv2.CAP_PROP_POS_FRAMES, index)
            ret, frame = src.read()
            if ret:
                result.append(format_frames(frame, output_size))
                
        
        # Select 1 frame from the last quarter
        src.set(cv2.CAP_PROP_POS_FRAMES, random.randint(last_part_start, last_part_end))
        ret, frame = src.read()
        if ret:
            result.append(format_frames(frame, output_size))

    src.release()
    result = np.array(result)

    return result

# %%
def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.

    Args:
      frame: Image that needs to resized and padded. 
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

# %%
def add_residual_block(input, filters, kernel_size):
  """
    Add residual blocks to the model. If the last dimensions of the input data
    and filter size does not match, project it such that last dimension matches.
  """
  out = ResidualMain(filters, 
                     kernel_size)(input)

  res = input
  # Using the Keras functional APIs, project the last dimension of the tensor to
  # match the new filter size
  if out.shape[-1] != input.shape[-1]:
    res = Project(out.shape[-1])(res)

  return layers.add([res, out])

# %%
def plot_history(history):
  """
    Plotting training and validation learning curves.

    Args:
      history: model history with all the metric measures
  """
  fig, (ax1, ax2) = plt.subplots(2)

  fig.set_size_inches(18.5, 10.5)

  # Plot loss
  ax1.set_title('Loss')
  ax1.plot(history.history['loss'], label = 'train')
  ax1.plot(history.history['val_loss'], label = 'test')
  ax1.set_ylabel('Loss')

  # Determine upper bound of y-axis
  max_loss = max(history.history['loss'] + history.history['val_loss'])

  ax1.set_ylim([0, np.ceil(max_loss)])
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation']) 

  # Plot accuracy
  ax2.set_title('Accuracy')
  ax2.plot(history.history['accuracy'],  label = 'train')
  ax2.plot(history.history['val_accuracy'], label = 'test')
  ax2.set_ylabel('Accuracy')
  ax2.set_ylim([0, 1])
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'])

  plt.show()

# %%
### added model to the input
def get_actual_predicted_labels(dataset, model): 
  """
    Create a list of actual ground truth values and the predictions from the model.

    Args:
      dataset: An iterable data structure, such as a TensorFlow Dataset, with features and labels.

    Return:
      Ground truth and predicted values for a particular dataset.
  """
  actual = [labels for _, labels in dataset.unbatch()]
  predicted = model.predict(dataset)

  actual = tf.stack(actual, axis=0)
  predicted = tf.concat(predicted, axis=0)
  predicted = tf.argmax(predicted, axis=1)

  return actual, predicted

# %%
def plot_confusion_matrix(actual, predicted, labels, ds_type):
  cm = tf.math.confusion_matrix(actual, predicted)
  ax = sns.heatmap(cm, annot=True, fmt='g')
  sns.set(rc={'figure.figsize':(12, 12)})
  sns.set(font_scale=1.4)
  ax.set_title('Confusion matrix of action recognition for ' + ds_type)
  ax.set_xlabel('Predicted Action')
  ax.set_ylabel('Actual Action')
  plt.xticks(rotation=90)
  plt.yticks(rotation=0)
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %%
def calculate_classification_metrics(y_actual, y_pred, labels):
  """
    Calculate the precision and recall of a classification model using the ground truth and
    predicted values. 

    Args:
      y_actual: Ground truth labels.
      y_pred: Predicted labels.
      labels: List of classification labels.

    Return:
      Precision and recall measures.
  """
  cm = tf.math.confusion_matrix(y_actual, y_pred)
  tp = np.diag(cm) # Diagonal represents true positives
  precision = dict()
  recall = dict()
  for i in range(len(labels)):
    col = cm[:, i]
    fp = np.sum(col) - tp[i] # Sum of column minus true positive is false negative

    row = cm[i, :]
    fn = np.sum(row) - tp[i] # Sum of row minus true positive, is false negative

    precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision 

    recall[labels[i]] = tp[i] / (tp[i] + fn) # Recall

  return precision, recall

# %% [markdown]
# ## Model structure

# %%
# Define the dimensions of one frame in the set of frames created
HEIGHT = 224
WIDTH = 224

# %%
input_shape = (None, 10, HEIGHT, WIDTH, 3)
input = layers.Input(shape=(input_shape[1:]))
x = input

x = Conv2Plus1D(filters=16, kernel_size=(3, 7, 7), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = ResizeVideo(HEIGHT // 2, WIDTH // 2)(x)

# Block 1
x = add_residual_block(x, 16, (3, 3, 3))
x = ResizeVideo(HEIGHT // 4, WIDTH // 4)(x)

# Block 2
x = add_residual_block(x, 32, (3, 3, 3))
x = ResizeVideo(HEIGHT // 8, WIDTH // 8)(x)

# Block 3
x = add_residual_block(x, 64, (3, 3, 3))
x = ResizeVideo(HEIGHT // 16, WIDTH // 16)(x)

# Block 4
x = add_residual_block(x, 128, (3, 3, 3))

x = layers.GlobalAveragePooling3D()(x)
x = layers.Flatten()(x)
x = layers.Dense(10)(x)

# %% [markdown]
# ## Checking frames

# %%
# Path to the main folder containing subdirectories with videos
main_folder_path = r"C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2"

# Loop through all subdirectories inside the main folder
for root, dirs, files in os.walk(main_folder_path):
    for dir in dirs:
        sub_folder_path = os.path.join(root, dir)

        # Loop through all video files inside the subdirectory
        for filename in os.listdir(sub_folder_path):
            if filename.endswith(".mp4"):
                # Open the video file
                video = cv2.VideoCapture(os.path.join(sub_folder_path, filename))

                # Get the total number of frames
                total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

                print(f"Number of frames in {os.path.join(sub_folder_path, filename)}: {total_frames}")

                # Release the video object
                video.release()
# Out:
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_13.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_31.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_33.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_34.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_49.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_52.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_54.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_60.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_67.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_69.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_7.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_72.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_73.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\background\background_8.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntCleaner_4.mp4: 45
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntCleaner_6.mp4: 19
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntCleaner_8_1.mp4: 54
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_15.mp4: 32
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_17_1.mp4: 17
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_19.mp4: 15
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_1_3.mp4: 53
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_2.mp4: 65
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_22_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_26.mp4: 49
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_27.mp4: 73
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_28_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_32_1.mp4: 18
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_41.mp4: 51
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_43.mp4: 38
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_44.mp4: 42
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_50.mp4: 43
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\test\IntCleaner\IntClient_9_2.mp4: 23
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_10.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_11.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_12.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_17.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_18.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_19.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_2.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_21.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_22.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_24.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_27.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_28.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_3.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_30.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_32.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_35.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_37.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_38.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_39.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_41.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_42.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_43.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_44.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_45.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_46.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_48.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_50.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_51.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_53.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_55.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_56.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_57.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_61.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_62.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_64.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_66.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_68.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_70.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_74.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\background\background_9.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntCleaner_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntCleaner_1.mp4: 108
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntCleaner_11_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntCleaner_11_1.mp4: 67
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntCleaner_2.mp4: 48
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntCleaner_3.mp4: 41
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntCleaner_5_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntCleaner_5_1.mp4: 23
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntCleaner_7.mp4: 20
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_0_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_0_1.mp4: 115
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_10_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_11.mp4: 58
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_12.mp4: 108
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_13.mp4: 82
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_17_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_18_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_18_2.mp4: 74
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_1_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_1_2.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_20.mp4: 67
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_21.mp4: 27
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_22_1.mp4: 117
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_23.mp4: 90
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_24_1.mp4: 81
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_25.mp4: 44
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_28_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_28_2.mp4: 102
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_29.mp4: 46
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_30.mp4: 22
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_31.mp4: 90
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_32_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_33.mp4: 64
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_34.mp4: 98
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_35.mp4: 45
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_36.mp4: 24
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_37.mp4: 80
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_38.mp4: 14
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_39.mp4: 23
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_4.mp4: 31
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_40.mp4: 71
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_42.mp4: 36
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_46.mp4: 58
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_47.mp4: 86
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_48.mp4: 111
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_51_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_51_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_6_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_6_1.mp4: 19
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_7_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_7_2.mp4: 69
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_8.mp4: 94
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\train\IntCleaner\IntClient_9_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_14.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_15.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_16.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_20.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_23.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_25.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_36.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_4.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_47.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_5.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_58.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_59.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_6.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_65.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\background\background_71.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntCleaner_10.mp4: 30
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntCleaner_8_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntCleaner_9.mp4: 8
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_10_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_10_2.mp4: 22
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_14.mp4: 57
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_16.mp4: 55
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_18_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_1_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_24_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_45.mp4: 42
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_49.mp4: 27
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_5.mp4: 56
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_51_2.mp4: 89
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_52.mp4: 26
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_53.mp4: 27
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_7_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test2\val\IntCleaner\IntClient_9_0.mp4: 120

# %% [markdown]
# # Int and Background

# %% [markdown]
# **2 classes:**
# + Background
# + Intcleaner + intclient
#
# Path: *Sep_Clips_Test2*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test2/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new2 = train_ds_new2.batch(batch_size)
val_ds_new2 = val_ds_new2.batch(batch_size)
test_ds_new2 = test_ds_new2.batch(batch_size)

# %%
model_new2 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new2))
model_new2.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new2, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new2.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history_new2 = model_new2.fit(x = train_ds_new2, epochs = 50, validation_data = val_ds_new2)
# Out:
# Epoch 1/50
# 95/95 [==============================] - 172s 2s/step - loss: 1.0494 - accuracy: 0.4737 - val_loss: 0.7251 - val_accuracy: 0.4545
# Epoch 2/50
# 95/95 [==============================] - 169s 2s/step - loss: 0.8674 - accuracy: 0.4211 - val_loss: 0.6974 - val_accuracy: 0.5455
# Epoch 3/50
# 95/95 [==============================] - 168s 2s/step - loss: 0.7936 - accuracy: 0.5053 - val_loss: 0.7252 - val_accuracy: 0.4545
# Epoch 4/50
# 95/95 [==============================] - 168s 2s/step - loss: 0.8031 - accuracy: 0.4211 - val_loss: 0.9196 - val_accuracy: 0.5455
# Epoch 5/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.8206 - accuracy: 0.4421 - val_loss: 0.7679 - val_accuracy: 0.5455
# Epoch 6/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7843 - accuracy: 0.5368 - val_loss: 0.9673 - val_accuracy: 0.4545
# Epoch 7/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.8155 - accuracy: 0.4947 - val_loss: 0.7108 - val_accuracy: 0.4545
# Epoch 8/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7789 - accuracy: 0.4842 - val_loss: 0.8037 - val_accuracy: 0.4545
# Epoch 9/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7411 - accuracy: 0.4842 - val_loss: 0.7029 - val_accuracy: 0.5455
# Epoch 10/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7391 - accuracy: 0.5158 - val_loss: 0.7094 - val_accuracy: 0.5455
# Epoch 11/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7307 - accuracy: 0.5263 - val_loss: 0.7088 - val_accuracy: 0.3333
# Epoch 12/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7248 - accuracy: 0.4947 - val_loss: 0.7596 - val_accuracy: 0.5455
# Epoch 13/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7638 - accuracy: 0.4947 - val_loss: 0.7950 - val_accuracy: 0.5455
# Epoch 14/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.6830 - accuracy: 0.5789 - val_loss: 0.7098 - val_accuracy: 0.3333
# Epoch 15/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7135 - accuracy: 0.5895 - val_loss: 0.7074 - val_accuracy: 0.5455
# Epoch 16/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7270 - accuracy: 0.4842 - val_loss: 0.7370 - val_accuracy: 0.5455
# Epoch 17/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.7102 - accuracy: 0.5474 - val_loss: 0.8281 - val_accuracy: 0.4545
# Epoch 18/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.7597 - accuracy: 0.4211 - val_loss: 0.7330 - val_accuracy: 0.4545
# Epoch 19/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.7204 - accuracy: 0.5158 - val_loss: 0.7270 - val_accuracy: 0.3333
# Epoch 20/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.7469 - accuracy: 0.4211 - val_loss: 0.7209 - val_accuracy: 0.3333
# 95/95 [==============================] - 167s 2s/step - loss: 0.6625 - accuracy: 0.6421 - val_loss: 0.7397 - val_accuracy: 0.4848
# Epoch 42/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.6641 - accuracy: 0.5789 - val_loss: 0.8083 - val_accuracy: 0.5455
# Epoch 43/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.6379 - accuracy: 0.6632 - val_loss: 0.7857 - val_accuracy: 0.4848
# Epoch 44/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.6431 - accuracy: 0.6947 - val_loss: 0.8053 - val_accuracy: 0.4848
# Epoch 45/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.6435 - accuracy: 0.6737 - val_loss: 0.7858 - val_accuracy: 0.4848
# Epoch 46/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.6315 - accuracy: 0.6526 - val_loss: 0.7818 - val_accuracy: 0.4848
# Epoch 47/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.6437 - accuracy: 0.6421 - val_loss: 0.8306 - val_accuracy: 0.5455
# Epoch 48/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.6648 - accuracy: 0.6632 - val_loss: 0.8787 - val_accuracy: 0.5455
# Epoch 49/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.6469 - accuracy: 0.6737 - val_loss: 0.7652 - val_accuracy: 0.4848
# Epoch 50/50
# 95/95 [==============================] - 167s 2s/step - loss: 0.6494 - accuracy: 0.6421 - val_loss: 0.7779 - val_accuracy: 0.4848

# %%
plot_history(history_new2)

# %%
model_new2.evaluate(test_ds_new2, return_dict=True)
# Out:
# 32/32 [==============================] - 28s 883ms/step - loss: 0.6322 - accuracy: 0.6562
# {'loss': 0.6322275400161743, 'accuracy': 0.65625}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new2, model_new2)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 95/95 [==============================] - 87s 909ms/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new2, model_new2)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 32/32 [==============================] - 28s 883ms/step

# %% [markdown]
# # Background and Interactions(jolt + chase + TS + int)

# %% [markdown]
# **2 classes:**
# + Background
# + Intclient + intcleaner + ts + jolt + chase
#
# + learning_rate = 0.001
#
# Path: *Sep_Clips_Test3*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new3_1 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new3_1 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new3_1 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test3/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new3_1 = train_ds_new3_1.batch(batch_size)
val_ds_new3_1 = val_ds_new3_1.batch(batch_size)
test_ds_new3_1 = test_ds_new3_1.batch(batch_size)

# %%
model_new3_1 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new3_1))
model_new3_1.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new3_1, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# 117/117 [==============================] - 208s 2s/step - loss: 0.6482 - accuracy: 0.6410 - val_loss: 0.6533 - val_accuracy: 0.6591
# Epoch 38/50
# 117/117 [==============================] - 207s 2s/step - loss: 0.6581 - accuracy: 0.6410 - val_loss: 0.6507 - val_accuracy: 0.6591
# Epoch 39/50
# 117/117 [==============================] - 206s 2s/step - loss: 0.6528 - accuracy: 0.6410 - val_loss: 0.6581 - val_accuracy: 0.6591
# Epoch 40/50
# 117/117 [==============================] - 208s 2s/step - loss: 0.6527 - accuracy: 0.6410 - val_loss: 0.6585 - val_accuracy: 0.6591
# Epoch 41/50
# 117/117 [==============================] - 208s 2s/step - loss: 0.6565 - accuracy: 0.6410 - val_loss: 0.6665 - val_accuracy: 0.6591
# Epoch 42/50
# 117/117 [==============================] - 206s 2s/step - loss: 0.6498 - accuracy: 0.6410 - val_loss: 0.6660 - val_accuracy: 0.6591
# Epoch 43/50
# 117/117 [==============================] - 207s 2s/step - loss: 0.6623 - accuracy: 0.6410 - val_loss: 0.6582 - val_accuracy: 0.6591
# Epoch 44/50
# 117/117 [==============================] - 207s 2s/step - loss: 0.6830 - accuracy: 0.6410 - val_loss: 0.6602 - val_accuracy: 0.6591
# Epoch 45/50
# 117/117 [==============================] - 208s 2s/step - loss: 0.6682 - accuracy: 0.6410 - val_loss: 0.6569 - val_accuracy: 0.6591
# Epoch 46/50
# 117/117 [==============================] - 209s 2s/step - loss: 0.6661 - accuracy: 0.6410 - val_loss: 0.6692 - val_accuracy: 0.6591
# Epoch 47/50
# 117/117 [==============================] - 208s 2s/step - loss: 0.6712 - accuracy: 0.6410 - val_loss: 0.6497 - val_accuracy: 0.6591
# Epoch 48/50
# 117/117 [==============================] - 209s 2s/step - loss: 0.6605 - accuracy: 0.6410 - val_loss: 0.6521 - val_accuracy: 0.6591
# Epoch 49/50
# 117/117 [==============================] - 209s 2s/step - loss: 0.6592 - accuracy: 0.6410 - val_loss: 0.6676 - val_accuracy: 0.6591
# Epoch 50/50
# 117/117 [==============================] - 208s 2s/step - loss: 0.6585 - accuracy: 0.6410 - val_loss: 0.6551 - val_accuracy: 0.6591

# %%
plot_history(history_new3_1)

# %%
model_new3_1.evaluate(test_ds_new3_1, return_dict=True)
# Out:
# 38/38 [==============================] - 34s 879ms/step - loss: 0.6559 - accuracy: 0.6316
# {'loss': 0.6558550596237183, 'accuracy': 0.6315789222717285}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new3_1, model_new3_1)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 106s 898ms/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new3_1, model_new3_1)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 33s 877ms/step

# %%
precision3_1, recall3_1 = calculate_classification_metrics(actual, predicted, labels) # Test dataset
# Out:
# C:\Users\BEE Team\AppData\Local\Temp\ipykernel_13196\3092751621.py:25: RuntimeWarning: invalid value encountered in long_scalars
#   precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision

# %%
precision3_1
# Out:
# {'IntCleaner': 0.631578947368421, 'background': nan}

# %%
recall3_1
# Out:
# {'IntCleaner': 1.0, 'background': 0.0}

# %% [markdown]
# # Int and Background

# %% [markdown]
# **2 classes:**
# + Background
# + Intcleaner + intclient
#
# Path: *Sep_Clips_Test2*
#
# + learning_rate = 0.001

# %%
model_new2_1 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new2))
model_new2_1.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new2_1, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new2_1.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.001), 
              metrics = ['accuracy'])

# %%
history_new2_1 = model_new2_1.fit(x = train_ds_new2, epochs = 50, validation_data = val_ds_new2)
# Out:
# Epoch 1/50
# 95/95 [==============================] - 171s 2s/step - loss: 0.6992 - accuracy: 0.5263 - val_loss: 0.7020 - val_accuracy: 0.3939
# Epoch 2/50
# 95/95 [==============================] - 168s 2s/step - loss: 0.6915 - accuracy: 0.5368 - val_loss: 0.7077 - val_accuracy: 0.5455
# Epoch 3/50
# 95/95 [==============================] - 168s 2s/step - loss: 0.6896 - accuracy: 0.5684 - val_loss: 0.7137 - val_accuracy: 0.5455
# Epoch 4/50
# 95/95 [==============================] - 168s 2s/step - loss: 0.6838 - accuracy: 0.5684 - val_loss: 0.7059 - val_accuracy: 0.4848
# Epoch 5/50
# 95/95 [==============================] - 169s 2s/step - loss: 0.6801 - accuracy: 0.6105 - val_loss: 0.7110 - val_accuracy: 0.4545
# Epoch 6/50
# 95/95 [==============================] - 168s 2s/step - loss: 0.7151 - accuracy: 0.5684 - val_loss: 0.7076 - val_accuracy: 0.5455
# Epoch 7/50
# 95/95 [==============================] - 168s 2s/step - loss: 0.6856 - accuracy: 0.5684 - val_loss: 0.7068 - val_accuracy: 0.5152
# Epoch 8/50
# 95/95 [==============================] - 168s 2s/step - loss: 0.6772 - accuracy: 0.5579 - val_loss: 0.7214 - val_accuracy: 0.5758
# Epoch 9/50
# 95/95 [==============================] - 169s 2s/step - loss: 0.6799 - accuracy: 0.5158 - val_loss: 0.7509 - val_accuracy: 0.5455
# Epoch 10/50
# 95/95 [==============================] - 169s 2s/step - loss: 0.6791 - accuracy: 0.6000 - val_loss: 0.7180 - val_accuracy: 0.6061
# Epoch 11/50
# 95/95 [==============================] - 169s 2s/step - loss: 0.6760 - accuracy: 0.5579 - val_loss: 0.7444 - val_accuracy: 0.4545
# Epoch 12/50
# 95/95 [==============================] - 171s 2s/step - loss: 0.6602 - accuracy: 0.6211 - val_loss: 0.7499 - val_accuracy: 0.5455
# Epoch 13/50
# 95/95 [==============================] - 171s 2s/step - loss: 0.6721 - accuracy: 0.5474 - val_loss: 0.7460 - val_accuracy: 0.3939
# Epoch 14/50
# 95/95 [==============================] - 172s 2s/step - loss: 0.6764 - accuracy: 0.5789 - val_loss: 0.7394 - val_accuracy: 0.6061
# Epoch 15/50
# 95/95 [==============================] - 171s 2s/step - loss: 0.6760 - accuracy: 0.5368 - val_loss: 0.7458 - val_accuracy: 0.3939
# Epoch 36/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.6675 - accuracy: 0.5895 - val_loss: 0.7599 - val_accuracy: 0.3636
# Epoch 37/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.6640 - accuracy: 0.6316 - val_loss: 0.7671 - val_accuracy: 0.3030
# Epoch 38/50
# 95/95 [==============================] - 165s 2s/step - loss: 0.6697 - accuracy: 0.6105 - val_loss: 0.7651 - val_accuracy: 0.2727
# Epoch 39/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.6550 - accuracy: 0.6316 - val_loss: 0.7786 - val_accuracy: 0.4545
# Epoch 40/50
# 95/95 [==============================] - 165s 2s/step - loss: 0.6490 - accuracy: 0.6421 - val_loss: 0.7743 - val_accuracy: 0.4545
# Epoch 41/50
# 95/95 [==============================] - 165s 2s/step - loss: 0.6536 - accuracy: 0.6000 - val_loss: 0.8063 - val_accuracy: 0.4848
# Epoch 42/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.6472 - accuracy: 0.6737 - val_loss: 0.8042 - val_accuracy: 0.3333
# Epoch 43/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.6759 - accuracy: 0.5789 - val_loss: 0.8001 - val_accuracy: 0.3333
# Epoch 44/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.6612 - accuracy: 0.6105 - val_loss: 0.7905 - val_accuracy: 0.5152
# Epoch 45/50
# 95/95 [==============================] - 165s 2s/step - loss: 0.6542 - accuracy: 0.6105 - val_loss: 0.8160 - val_accuracy: 0.3636
# Epoch 46/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.6600 - accuracy: 0.6000 - val_loss: 0.7778 - val_accuracy: 0.4242
# Epoch 47/50
# 95/95 [==============================] - 166s 2s/step - loss: 0.6531 - accuracy: 0.5895 - val_loss: 0.7983 - val_accuracy: 0.4545
# Epoch 48/50
# 95/95 [==============================] - 165s 2s/step - loss: 0.6557 - accuracy: 0.5789 - val_loss: 0.7910 - val_accuracy: 0.4545
# Epoch 49/50
# 95/95 [==============================] - 165s 2s/step - loss: 0.6487 - accuracy: 0.6842 - val_loss: 0.8060 - val_accuracy: 0.3939
# Epoch 50/50
# 95/95 [==============================] - 165s 2s/step - loss: 0.6410 - accuracy: 0.6632 - val_loss: 0.7778 - val_accuracy: 0.4848

# %%
plot_history(history_new2_1)

# %%
model_new2_1.evaluate(test_ds_new2, return_dict=True)
# Out:
# 32/32 [==============================] - 28s 882ms/step - loss: 0.6325 - accuracy: 0.6562
# {'loss': 0.6324875950813293, 'accuracy': 0.65625}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new2, model_new2_1)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 95/95 [==============================] - 87s 911ms/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new2, model_new2_1)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 32/32 [==============================] - 29s 886ms/step
