# %% [markdown]
# **Table of Contents:**
# <br> **1- Video classification**
# + Imports
# + Classes
# + Functions
# + Model Structure
# + Model Stucture
# + Checking Frames
#
# <br> **2- Data with everything**
# <br> **3- Data joined interactions and jolt+run**
# <br> **4- Int and background**
# <br> **5- Background and Interactions(jolt+chase+TS+Ints)**
# <br> **6- Training with one video**
# <br> **7- Background and Interactions(jolt+chase+TS+Ints) lr=0.001**
# <br> **8- Background and Interactions(jolt+chase+TS+Ints) lr=0.01**

# %% [markdown]
# # Video Classification
# https://www.tensorflow.org/tutorials/video/video_classification

# %% [markdown]
# ## Imports

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.11.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\users\public\new\envs\tensorflowraul\lib\site-packages
# Requires: tensorflow-intel
# Required-by:
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\bee team\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\public\new\envs\tensorflowraul\lib\site-packages)

# %%
import tqdm
import random
import pathlib
import itertools
import collections

import cv2
import einops
import numpy as np
import remotezip as rz
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers

from pathlib import Path

# %% [markdown]
# ## Classes:

# %%
class FrameGenerator:
  def __init__(self, path, n_frames, training = False):
    """ Returns a set of frames with their associated label. 

      Args:
        path: Video file paths.
        n_frames: Number of frames. 
        training: Boolean to determine if training dataset is being created.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.mp4'))
    classes = [p.parent.name for p in video_paths] 
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path, self.n_frames) 
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %%
class Conv2Plus1D(keras.layers.Layer):
  def __init__(self, filters, kernel_size, padding):
    """
      A sequence of convolutional layers that first apply the convolution operation over the
      spatial dimensions, and then the temporal dimension. 
    """
    super().__init__()
    self.seq = keras.Sequential([  
        # Spatial decomposition
        layers.Conv3D(filters=filters,
                      kernel_size=(1, kernel_size[1], kernel_size[2]),
                      padding=padding),
        # Temporal decomposition
        layers.Conv3D(filters=filters, 
                      kernel_size=(kernel_size[0], 1, 1),
                      padding=padding)
        ])

  def call(self, x):
    return self.seq(x)

# %%
class ResidualMain(keras.layers.Layer):
  """
    Residual block of the model with convolution, layer normalization, and the
    activation function, ReLU.
  """
  def __init__(self, filters, kernel_size):
    super().__init__()
    self.seq = keras.Sequential([
        Conv2Plus1D(filters=filters,
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization(),
        layers.ReLU(),
        Conv2Plus1D(filters=filters, 
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %%
class Project(keras.layers.Layer):
  """
    Project certain dimensions of the tensor as the data is passed through different 
    sized filters and downsampled. 
  """
  def __init__(self, units):
    super().__init__()
    self.seq = keras.Sequential([
        layers.Dense(units),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %%
class ResizeVideo(keras.layers.Layer):
  def __init__(self, height, width):
    super().__init__()
    self.height = height
    self.width = width
    self.resizing_layer = layers.Resizing(self.height, self.width)

  def call(self, video):
    """
      Use the einops library to resize the tensor.  

      Args:
        video: Tensor representation of the video, in the form of a set of frames.

      Return:
        A downsampled size of the video according to the new height and width it should be resized to.
    """
    # b stands for batch size, t stands for time, h stands for height, 
    # w stands for width, and c stands for the number of channels.
    old_shape = einops.parse_shape(video, 'b t h w c')
    images = einops.rearrange(video, 'b t h w c -> (b t) h w c')
    images = self.resizing_layer(images)
    videos = einops.rearrange(
        images, '(b t) h w c -> b t h w c',
        t = old_shape['t'])
    return videos

# %% [markdown]
# ## Functions

# %%
def frames_from_video_file(video_path, n_frames, output_size = (224,224), frame_step = 60):
  """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
  """
  # Read each video frame by frame
  result = []
  src = cv2.VideoCapture(str(video_path))  

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frames(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frames(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

# %%
def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.

    Args:
      frame: Image that needs to resized and padded. 
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

# %%
def add_residual_block(input, filters, kernel_size):
  """
    Add residual blocks to the model. If the last dimensions of the input data
    and filter size does not match, project it such that last dimension matches.
  """
  out = ResidualMain(filters, 
                     kernel_size)(input)

  res = input
  # Using the Keras functional APIs, project the last dimension of the tensor to
  # match the new filter size
  if out.shape[-1] != input.shape[-1]:
    res = Project(out.shape[-1])(res)

  return layers.add([res, out])

# %%
def plot_history(history):
  """
    Plotting training and validation learning curves.

    Args:
      history: model history with all the metric measures
  """
  fig, (ax1, ax2) = plt.subplots(2)

  fig.set_size_inches(18.5, 10.5)

  # Plot loss
  ax1.set_title('Loss')
  ax1.plot(history.history['loss'], label = 'train')
  ax1.plot(history.history['val_loss'], label = 'test')
  ax1.set_ylabel('Loss')

  # Determine upper bound of y-axis
  max_loss = max(history.history['loss'] + history.history['val_loss'])

  ax1.set_ylim([0, np.ceil(max_loss)])
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation']) 

  # Plot accuracy
  ax2.set_title('Accuracy')
  ax2.plot(history.history['accuracy'],  label = 'train')
  ax2.plot(history.history['val_accuracy'], label = 'test')
  ax2.set_ylabel('Accuracy')
  ax2.set_ylim([0, 1])
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'])

  plt.show()

# %%
### added model to the input
def get_actual_predicted_labels(dataset, model): 
  """
    Create a list of actual ground truth values and the predictions from the model.

    Args:
      dataset: An iterable data structure, such as a TensorFlow Dataset, with features and labels.

    Return:
      Ground truth and predicted values for a particular dataset.
  """
  actual = [labels for _, labels in dataset.unbatch()]
  predicted = model.predict(dataset)

  actual = tf.stack(actual, axis=0)
  predicted = tf.concat(predicted, axis=0)
  predicted = tf.argmax(predicted, axis=1)

  return actual, predicted

# %%
def plot_confusion_matrix(actual, predicted, labels, ds_type):
  cm = tf.math.confusion_matrix(actual, predicted)
  ax = sns.heatmap(cm, annot=True, fmt='g')
  sns.set(rc={'figure.figsize':(12, 12)})
  sns.set(font_scale=1.4)
  ax.set_title('Confusion matrix of action recognition for ' + ds_type)
  ax.set_xlabel('Predicted Action')
  ax.set_ylabel('Actual Action')
  plt.xticks(rotation=90)
  plt.yticks(rotation=0)
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %%
def calculate_classification_metrics(y_actual, y_pred, labels):
  """
    Calculate the precision and recall of a classification model using the ground truth and
    predicted values. 

    Args:
      y_actual: Ground truth labels.
      y_pred: Predicted labels.
      labels: List of classification labels.

    Return:
      Precision and recall measures.
  """
  cm = tf.math.confusion_matrix(y_actual, y_pred)
  tp = np.diag(cm) # Diagonal represents true positives
  precision = dict()
  recall = dict()
  for i in range(len(labels)):
    col = cm[:, i]
    fp = np.sum(col) - tp[i] # Sum of column minus true positive is false negative

    row = cm[i, :]
    fn = np.sum(row) - tp[i] # Sum of row minus true positive, is false negative

    precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision 

    recall[labels[i]] = tp[i] / (tp[i] + fn) # Recall

  return precision, recall

# %% [markdown]
# ## Model structure

# %%
# Define the dimensions of one frame in the set of frames created
HEIGHT = 224
WIDTH = 224

# %%
input_shape = (None, 10, HEIGHT, WIDTH, 3)
input = layers.Input(shape=(input_shape[1:]))
x = input

x = Conv2Plus1D(filters=16, kernel_size=(3, 7, 7), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = ResizeVideo(HEIGHT // 2, WIDTH // 2)(x)

# Block 1
x = add_residual_block(x, 16, (3, 3, 3))
x = ResizeVideo(HEIGHT // 4, WIDTH // 4)(x)

# Block 2
x = add_residual_block(x, 32, (3, 3, 3))
x = ResizeVideo(HEIGHT // 8, WIDTH // 8)(x)

# Block 3
x = add_residual_block(x, 64, (3, 3, 3))
x = ResizeVideo(HEIGHT // 16, WIDTH // 16)(x)

# Block 4
x = add_residual_block(x, 128, (3, 3, 3))

x = layers.GlobalAveragePooling3D()(x)
x = layers.Flatten()(x)
x = layers.Dense(10)(x)

# %% [markdown]
# ## Checking frames

# %%
import cv2
import os

# Path to the main folder containing subdirectories with videos
main_folder_path = r"C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test"

# Loop through all subdirectories inside the main folder
for root, dirs, files in os.walk(main_folder_path):
    for dir in dirs:
        sub_folder_path = os.path.join(root, dir)

        # Loop through all video files inside the subdirectory
        for filename in os.listdir(sub_folder_path):
            if filename.endswith(".mp4") or filename.endswith(".avi"):
                # Open the video file
                video = cv2.VideoCapture(os.path.join(sub_folder_path, filename))

                # Get the total number of frames
                total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

                print(f"Number of frames in {os.path.join(sub_folder_path, filename)}: {total_frames}")

                # Release the video object
                video.release()
# Out:
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background
1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_8_2.mp4: 120

# %% [markdown]
# # Data with everything

# %% [markdown]
# **6 classes:**
# + Background
# + Intcleaner
# + intclient
# + TS
# + Jolt
# + Chase
#
# Path: *Sep_Clips*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)

# %%
model = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds))
model.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history = model.fit(x = train_ds, epochs = 50, validation_data = val_ds)
# Out:
# Epoch 1/50
# 117/117 [==============================] - 242s 2s/step - loss: 1.7395 - accuracy: 0.4359 - val_loss: 1.8902 - val_accuracy: 0.2045
# Epoch 2/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.4520 - accuracy: 0.3846 - val_loss: 1.6168 - val_accuracy: 0.3409
# Epoch 3/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.3896 - accuracy: 0.4701 - val_loss: 1.8056 - val_accuracy: 0.3409
# Epoch 4/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.4349 - accuracy: 0.3761 - val_loss: 1.4758 - val_accuracy: 0.3409
# Epoch 5/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.3494 - accuracy: 0.4017 - val_loss: 1.6323 - val_accuracy: 0.3409
# Epoch 6/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.3248 - accuracy: 0.4188 - val_loss: 1.9589 - val_accuracy: 0.3409
# Epoch 7/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.3312 - accuracy: 0.4359 - val_loss: 1.9257 - val_accuracy: 0.3409
# Epoch 8/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.3658 - accuracy: 0.3675 - val_loss: 1.6522 - val_accuracy: 0.3409
# Epoch 9/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2993 - accuracy: 0.3846 - val_loss: 1.9561 - val_accuracy: 0.3409
# Epoch 10/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2612 - accuracy: 0.4017 - val_loss: 1.6890 - val_accuracy: 0.3409
# Epoch 11/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2793 - accuracy: 0.4103 - val_loss: 1.6637 - val_accuracy: 0.3409
# Epoch 12/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2844 - accuracy: 0.4530 - val_loss: 1.6509 - val_accuracy: 0.3409
# Epoch 13/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2593 - accuracy: 0.4615 - val_loss: 1.6128 - val_accuracy: 0.3409
# Epoch 14/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2918 - accuracy: 0.4530 - val_loss: 1.6902 - val_accuracy: 0.3409
# Epoch 15/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2424 - accuracy: 0.4701 - val_loss: 1.7868 - val_accuracy: 0.5227
# Epoch 16/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2887 - accuracy: 0.4444 - val_loss: 1.8019 - val_accuracy: 0.3409
# Epoch 17/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2497 - accuracy: 0.4444 - val_loss: 2.0539 - val_accuracy: 0.3409
# Epoch 18/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.3467 - accuracy: 0.2991 - val_loss: 1.7583 - val_accuracy: 0.5227
# Epoch 19/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2376 - accuracy: 0.4872 - val_loss: 2.0464 - val_accuracy: 0.3409
# Epoch 20/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2912 - accuracy: 0.4017 - val_loss: 1.8459 - val_accuracy: 0.3409
# Epoch 21/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2199 - accuracy: 0.4615 - val_loss: 1.7957 - val_accuracy: 0.3409
# Epoch 22/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2474 - accuracy: 0.3846 - val_loss: 1.8586 - val_accuracy: 0.3409
# Epoch 23/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2597 - accuracy: 0.3590 - val_loss: 1.8020 - val_accuracy: 0.3409
# Epoch 24/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2354 - accuracy: 0.4274 - val_loss: 2.0058 - val_accuracy: 0.3409
# Epoch 25/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2413 - accuracy: 0.4530 - val_loss: 1.7788 - val_accuracy: 0.3409
# Epoch 26/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2584 - accuracy: 0.3846 - val_loss: 1.8106 - val_accuracy: 0.3409
# Epoch 27/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2364 - accuracy: 0.3846 - val_loss: 1.9290 - val_accuracy: 0.3409
# Epoch 28/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2299 - accuracy: 0.4274 - val_loss: 1.9027 - val_accuracy: 0.3409
# Epoch 29/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2459 - accuracy: 0.4188 - val_loss: 1.8780 - val_accuracy: 0.3409
# Epoch 30/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2310 - accuracy: 0.4530 - val_loss: 1.9139 - val_accuracy: 0.3409
# Epoch 31/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2301 - accuracy: 0.4701 - val_loss: 1.9061 - val_accuracy: 0.3409
# Epoch 32/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2324 - accuracy: 0.3590 - val_loss: 1.9463 - val_accuracy: 0.3409
# Epoch 33/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2493 - accuracy: 0.3846 - val_loss: 1.9446 - val_accuracy: 0.3409
# Epoch 34/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2288 - accuracy: 0.4103 - val_loss: 2.0256 - val_accuracy: 0.3409
# Epoch 35/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2379 - accuracy: 0.3761 - val_loss: 1.9116 - val_accuracy: 0.3409
# Epoch 36/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2388 - accuracy: 0.4103 - val_loss: 1.8674 - val_accuracy: 0.3409
# Epoch 37/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2318 - accuracy: 0.4359 - val_loss: 1.9093 - val_accuracy: 0.3409
# Epoch 38/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2224 - accuracy: 0.3846 - val_loss: 1.9935 - val_accuracy: 0.3409
# Epoch 39/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2494 - accuracy: 0.4103 - val_loss: 1.9067 - val_accuracy: 0.3409
# Epoch 40/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2284 - accuracy: 0.4188 - val_loss: 1.8923 - val_accuracy: 0.3409
# Epoch 41/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2398 - accuracy: 0.3932 - val_loss: 1.9553 - val_accuracy: 0.3409
# Epoch 42/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2100 - accuracy: 0.4103 - val_loss: 2.0548 - val_accuracy: 0.3409
# Epoch 43/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2399 - accuracy: 0.4615 - val_loss: 1.9826 - val_accuracy: 0.3409
# Epoch 44/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2127 - accuracy: 0.4530 - val_loss: 1.9544 - val_accuracy: 0.3409
# Epoch 45/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2233 - accuracy: 0.4188 - val_loss: 2.0639 - val_accuracy: 0.3409
# Epoch 46/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2404 - accuracy: 0.3675 - val_loss: 1.9538 - val_accuracy: 0.3409
# Epoch 47/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2163 - accuracy: 0.4188 - val_loss: 1.8925 - val_accuracy: 0.3409
# Epoch 48/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2285 - accuracy: 0.4103 - val_loss: 1.9578 - val_accuracy: 0.3409
# Epoch 49/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2612 - accuracy: 0.3846 - val_loss: 2.1491 - val_accuracy: 0.3409
# Epoch 50/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.2301 - accuracy: 0.4444 - val_loss: 1.9704 - val_accuracy: 0.3409

# %%
plot_history(history)

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 38/38 [==============================] - 35s 905ms/step - loss: 2.6353 - accuracy: 0.0000e+00
# {'loss': 2.6353373527526855, 'accuracy': 0.0}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds, model)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 124s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds, model)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 35s 904ms/step

# %%
precision, recall = calculate_classification_metrics(actual, predicted, labels) # Test dataset
# Out:
# C:\Users\BEE Team\AppData\Local\Temp\ipykernel_13864\3092751621.py:25: RuntimeWarning: invalid value encountered in long_scalars
#   precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision
# C:\Users\BEE Team\AppData\Local\Temp\ipykernel_13864\3092751621.py:27: RuntimeWarning: invalid value encountered in long_scalars
#   recall[labels[i]] = tp[i] / (tp[i] + fn) # Recall

# %%
precision
# Out:
# {'IntCleaner': nan,
#  'IntClient': nan,
#  'Jolt': nan,
#  'Run': nan,
#  'TS': nan,
#  'background': 0.0}

# %%
recall
# Out:
# {'IntCleaner': 0.0,
#  'IntClient': 0.0,
#  'Jolt': 0.0,
#  'Run': 0.0,
#  'TS': 0.0,
#  'background': nan}

# %% [markdown]
# # Data joined interactions and jolt+run

# %% [markdown]
# **4 classes:**
# + Background
# + Intcleaner + intclient
# + TS
# + Jolt + Chase
#
# Path: *Sep_Clips_Test*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new = train_ds_new.batch(batch_size)
val_ds_new = val_ds_new.batch(batch_size)
test_ds_new = test_ds_new.batch(batch_size)

# %%
model_new = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new))
model_new.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history_new = model_new.fit(x = train_ds_new, epochs = 50, validation_data = val_ds_new)
# Out:
# Epoch 1/50
# 117/117 [==============================] - 236s 2s/step - loss: 1.6315 - accuracy: 0.3932 - val_loss: 1.3114 - val_accuracy: 0.4091
# Epoch 2/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.1075 - accuracy: 0.3846 - val_loss: 1.4029 - val_accuracy: 0.4091
# Epoch 3/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.0317 - accuracy: 0.4957 - val_loss: 1.4340 - val_accuracy: 0.1818
# Epoch 4/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.0296 - accuracy: 0.4615 - val_loss: 1.4494 - val_accuracy: 0.4091
# Epoch 5/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.0380 - accuracy: 0.4017 - val_loss: 1.5549 - val_accuracy: 0.3409
# Epoch 6/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9911 - accuracy: 0.4615 - val_loss: 1.6417 - val_accuracy: 0.3409
# Epoch 7/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.0295 - accuracy: 0.4701 - val_loss: 1.5309 - val_accuracy: 0.2727
# Epoch 8/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.0064 - accuracy: 0.4701 - val_loss: 1.5970 - val_accuracy: 0.3409
# Epoch 9/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9848 - accuracy: 0.4017 - val_loss: 1.8597 - val_accuracy: 0.3409
# Epoch 10/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.0071 - accuracy: 0.4444 - val_loss: 1.6709 - val_accuracy: 0.3409
# Epoch 11/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.0023 - accuracy: 0.4103 - val_loss: 1.6844 - val_accuracy: 0.3409
# Epoch 12/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9969 - accuracy: 0.4530 - val_loss: 1.9149 - val_accuracy: 0.3409
# Epoch 13/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.0168 - accuracy: 0.4701 - val_loss: 1.6331 - val_accuracy: 0.3409
# Epoch 14/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9866 - accuracy: 0.4530 - val_loss: 1.8484 - val_accuracy: 0.3409
# Epoch 15/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9984 - accuracy: 0.3590 - val_loss: 1.6986 - val_accuracy: 0.3409
# Epoch 16/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9980 - accuracy: 0.3846 - val_loss: 1.5945 - val_accuracy: 0.3409
# Epoch 17/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.0024 - accuracy: 0.4872 - val_loss: 1.6074 - val_accuracy: 0.1818
# Epoch 18/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9681 - accuracy: 0.4701 - val_loss: 1.8340 - val_accuracy: 0.3409
# Epoch 19/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.0131 - accuracy: 0.4444 - val_loss: 1.6708 - val_accuracy: 0.3409
# Epoch 20/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9747 - accuracy: 0.4444 - val_loss: 1.7167 - val_accuracy: 0.3409
# Epoch 21/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9638 - accuracy: 0.4359 - val_loss: 1.7513 - val_accuracy: 0.3409
# Epoch 22/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9534 - accuracy: 0.4359 - val_loss: 1.6811 - val_accuracy: 0.4091
# Epoch 23/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9781 - accuracy: 0.4957 - val_loss: 1.8681 - val_accuracy: 0.3409
# Epoch 24/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9903 - accuracy: 0.4615 - val_loss: 1.6324 - val_accuracy: 0.4091
# Epoch 25/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9854 - accuracy: 0.4701 - val_loss: 1.6807 - val_accuracy: 0.3409
# Epoch 26/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9932 - accuracy: 0.4359 - val_loss: 1.8325 - val_accuracy: 0.3409
# Epoch 27/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9527 - accuracy: 0.4530 - val_loss: 1.6517 - val_accuracy: 0.4091
# Epoch 28/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9814 - accuracy: 0.4017 - val_loss: 1.7148 - val_accuracy: 0.3409
# Epoch 29/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9473 - accuracy: 0.4872 - val_loss: 1.8671 - val_accuracy: 0.3409
# Epoch 30/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9723 - accuracy: 0.4615 - val_loss: 1.6707 - val_accuracy: 0.3409
# Epoch 31/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9688 - accuracy: 0.4444 - val_loss: 1.8345 - val_accuracy: 0.3409
# Epoch 32/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9825 - accuracy: 0.4274 - val_loss: 1.7671 - val_accuracy: 0.3409
# Epoch 33/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9497 - accuracy: 0.4444 - val_loss: 1.7433 - val_accuracy: 0.4091
# Epoch 34/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9897 - accuracy: 0.3675 - val_loss: 1.6999 - val_accuracy: 0.3636
# Epoch 35/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9579 - accuracy: 0.5299 - val_loss: 1.7867 - val_accuracy: 0.3409
# Epoch 36/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9644 - accuracy: 0.4872 - val_loss: 1.6825 - val_accuracy: 0.4091
# Epoch 37/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9289 - accuracy: 0.5299 - val_loss: 1.8434 - val_accuracy: 0.4091
# Epoch 38/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9474 - accuracy: 0.4530 - val_loss: 1.8788 - val_accuracy: 0.3409
# Epoch 39/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9709 - accuracy: 0.4786 - val_loss: 1.7341 - val_accuracy: 0.4318
# Epoch 40/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9688 - accuracy: 0.4103 - val_loss: 1.7119 - val_accuracy: 0.4091
# Epoch 41/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9431 - accuracy: 0.4786 - val_loss: 1.7232 - val_accuracy: 0.4091
# Epoch 42/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9546 - accuracy: 0.4530 - val_loss: 1.6959 - val_accuracy: 0.4091
# Epoch 43/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9578 - accuracy: 0.4017 - val_loss: 1.7408 - val_accuracy: 0.4545
# Epoch 44/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9337 - accuracy: 0.4530 - val_loss: 1.8744 - val_accuracy: 0.4091
# Epoch 45/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9403 - accuracy: 0.4530 - val_loss: 1.7683 - val_accuracy: 0.3864
# Epoch 46/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9404 - accuracy: 0.4530 - val_loss: 1.7402 - val_accuracy: 0.4091
# Epoch 47/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.9385 - accuracy: 0.4188 - val_loss: 1.8091 - val_accuracy: 0.5227
# Epoch 48/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9270 - accuracy: 0.5128 - val_loss: 1.7784 - val_accuracy: 0.4318
# Epoch 49/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.9435 - accuracy: 0.5043 - val_loss: 1.7941 - val_accuracy: 0.5227
# Epoch 50/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9324 - accuracy: 0.4615 - val_loss: 1.8231 - val_accuracy: 0.3864

# %%
plot_history(history_new)

# %%
model_new.evaluate(test_ds_new, return_dict=True)
# Out:
# 38/38 [==============================] - 35s 909ms/step - loss: 1.4055 - accuracy: 0.4737
# {'loss': 1.4054858684539795, 'accuracy': 0.4736842215061188}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new, model_new)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 124s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new, model_new)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 35s 904ms/step

# %% [markdown]
# # Int and Background

# %% [markdown]
# **2 classes:**
# + Background
# + Intcleaner + intclient
#
# Path: *Sep_Clips_Test2*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test2/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new2 = train_ds_new2.batch(batch_size)
val_ds_new2 = val_ds_new2.batch(batch_size)
test_ds_new2 = test_ds_new2.batch(batch_size)

# %%
model_new2 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new2))
model_new2.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new2, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new2.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history_new2 = model_new2.fit(x = train_ds_new2, epochs = 50, validation_data = val_ds_new2)
# Out:
# Epoch 1/50
# 95/95 [==============================] - 199s 2s/step - loss: 1.2784 - accuracy: 0.5158 - val_loss: 0.5618 - val_accuracy: 0.7576
# Epoch 2/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.
50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5792 - accuracy: 0.6211 - val_loss: 0.5204 - val_accuracy: 0.5758
# Epoch 32/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5701 - accuracy: 0.6211 - val_loss: 0.4774 - val_accuracy: 0.7576
# Epoch 33/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5835 - accuracy: 0.6211 - val_loss: 0.4994 - val_accuracy: 0.5758
# Epoch 34/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5704 - accuracy: 0.6526 - val_loss: 0.4885 - val_accuracy: 0.6970
# Epoch 35/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.6003 - accuracy: 0.6211 - val_loss: 0.5065 - val_accuracy: 0.5758
# Epoch 36/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5832 - accuracy: 0.6105 - val_loss: 0.4787 - val_accuracy: 0.7576
# Epoch 37/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5816 - accuracy: 0.5789 - val_loss: 0.5032 - val_accuracy: 0.5758
# Epoch 38/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5719 - accuracy: 0.6632 - val_loss: 0.4846 - val_accuracy: 0.7576
# Epoch 39/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5817 - accuracy: 0.6211 - val_loss: 0.5211 - val_accuracy: 0.5758
# Epoch 40/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5731 - accuracy: 0.6000 - val_loss: 0.4962 - val_accuracy: 0.5758
# Epoch 41/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5656 - accuracy: 0.6211 - val_loss: 0.6895 - val_accuracy: 0.5455
# Epoch 42/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5761 - accuracy: 0.6211 - val_loss: 0.4913 - val_accuracy: 0.5758
# Epoch 43/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5588 - accuracy: 0.6632 - val_loss: 0.4887 - val_accuracy: 0.6667
# Epoch 44/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5674 - accuracy: 0.6737 - val_loss: 0.5216 - val_accuracy: 0.5758
# Epoch 45/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5563 - accuracy: 0.6526 - val_loss: 0.5743 - val_accuracy: 0.5455
# Epoch 46/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5583 - accuracy: 0.6526 - val_loss: 0.4872 - val_accuracy: 0.5758
# Epoch 47/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.6010 - accuracy: 0.6211 - val_loss: 0.4830 - val_accuracy: 0.7576
# Epoch 48/50
# 95/95 [==============================] - 198s 2s/step - loss: 0.5778 - accuracy: 0.6000 - val_loss: 0.5102 - val_accuracy: 0.5758
# Epoch 49/50
# 95/95 [==============================] - 196s 2s/step - loss: 0.5744 - accuracy: 0.6105 - val_loss: 0.5446 - val_accuracy: 0.5455
# Epoch 50/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5471 - accuracy: 0.7053 - val_loss: 0.4721 - val_accuracy: 0.7576

# %%
plot_history(history_new2)

# %%
model_new2.evaluate(test_ds_new2, return_dict=True)
# Out:
# 32/32 [==============================] - 31s 963ms/step - loss: 0.2968 - accuracy: 0.8750
# {'loss': 0.2968128025531769, 'accuracy': 0.875}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new2, model_new2)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 95/95 [==============================] - 110s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new2, model_new2)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 32/32 [==============================] - 31s 962ms/step

# %% [markdown]
# # Background and Interactions(jolt + chase + TS + int)

# %% [markdown]
# **2 classes:**
# + Background
# + Intclient + intcleaner + ts + jolt + chase
#
# Path: *Sep_Clips_Test3*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new3 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new3 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new3 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test3/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new3 = train_ds_new3.batch(batch_size)
val_ds_new3 = val_ds_new3.batch(batch_size)
test_ds_new3 = test_ds_new3.batch(batch_size)

# %%
model_new3 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new3))
model_new3.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new3, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new3.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history_new3 = model_new3.fit(x = train_ds_new3, epochs = 50, validation_data = val_ds_new3)
# Out:
# Epoch 1/50
# 117/117 [==============================] - 236s 2s/step - loss: 0.5225 - accuracy: 0.6581 - val_loss: 0.4701 - val_accuracy: 0.5909
# Epoch 2/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.
50
# 117/117 [==============================] - 232s 2s/step - loss: 0.5057 - accuracy: 0.7009 - val_loss: 0.4834 - val_accuracy: 0.6591
# Epoch 31/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.4874 - accuracy: 0.7436 - val_loss: 0.5455 - val_accuracy: 0.6364
# Epoch 32/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.4970 - accuracy: 0.7436 - val_loss: 0.4683 - val_accuracy: 0.6591
# Epoch 33/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4885 - accuracy: 0.7436 - val_loss: 0.4846 - val_accuracy: 0.6591
# Epoch 34/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.4818 - accuracy: 0.7009 - val_loss: 0.5010 - val_accuracy: 0.6364
# Epoch 35/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.5044 - accuracy: 0.6410 - val_loss: 0.4614 - val_accuracy: 0.7045
# Epoch 36/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4976 - accuracy: 0.7009 - val_loss: 0.4601 - val_accuracy: 0.7045
# Epoch 37/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4684 - accuracy: 0.6923 - val_loss: 0.5308 - val_accuracy: 0.6591
# Epoch 38/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.5168 - accuracy: 0.6838 - val_loss: 0.4952 - val_accuracy: 0.6591
# Epoch 39/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.5011 - accuracy: 0.7350 - val_loss: 0.4660 - val_accuracy: 0.6591
# Epoch 40/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4868 - accuracy: 0.7436 - val_loss: 0.4696 - val_accuracy: 0.6591
# Epoch 41/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4935 - accuracy: 0.7265 - val_loss: 0.4627 - val_accuracy: 0.6364
# Epoch 42/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4833 - accuracy: 0.7350 - val_loss: 0.4728 - val_accuracy: 0.6591
# Epoch 43/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4892 - accuracy: 0.7179 - val_loss: 0.4664 - val_accuracy: 0.5909
# Epoch 44/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4867 - accuracy: 0.7179 - val_loss: 0.4732 - val_accuracy: 0.6591
# Epoch 45/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.5034 - accuracy: 0.7350 - val_loss: 0.4683 - val_accuracy: 0.6591
# Epoch 46/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.4865 - accuracy: 0.7350 - val_loss: 0.4780 - val_accuracy: 0.6591
# Epoch 47/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.4903 - accuracy: 0.6923 - val_loss: 0.5082 - val_accuracy: 0.6364
# Epoch 48/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4912 - accuracy: 0.7265 - val_loss: 0.4818 - val_accuracy: 0.6591
# Epoch 49/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4806 - accuracy: 0.7179 - val_loss: 0.4883 - val_accuracy: 0.6591
# Epoch 50/50
# 117/117 [==============================] - 232s 2s/step - loss: 0.4936 - accuracy: 0.6923 - val_loss: 0.4744 - val_accuracy: 0.6591

# %%
plot_history(history_new3)

# %%
model_new3.evaluate(test_ds_new3, return_dict=True)
# Out:
# 38/38 [==============================] - 35s 908ms/step - loss: 0.3177 - accuracy: 0.7895
# {'loss': 0.31770002841949463, 'accuracy': 0.7894737124443054}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new3, model_new3)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 124s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new3, model_new3)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 35s 904ms/step

# %%
precision_3, recall_3 = calculate_classification_metrics(actual, predicted, labels) # Test dataset

# %%
precision_3
# Out:
# {'IntCleaner': 0.7666666666666667, 'background': 0.875}

# %%
recall_3
# Out:
# {'IntCleaner': 0.9583333333333334, 'background': 0.5}

# %% [markdown]
# # Training with one video (?)

# %% [markdown]
# + **1 class** with 1 video in trainning:
#
# Path: *Sep_Clips_Test5*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new5 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test5/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new5 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test5/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new5 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test5/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new5 = train_ds_new5.batch(batch_size)
val_ds_new5 = val_ds_new5.batch(batch_size)
test_ds_new5 = test_ds_new5.batch(batch_size)

# %%
model_new5 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new5))
model_new5.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new5, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new5.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history_new5 = model_new5.fit(x = train_ds_new5, epochs = 50, validation_data = val_ds_new5)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 30s 30s/step - loss: 0.5335 - accuracy: 1.0000 - val_loss: 0.2839 - val_accuracy: 0.8966
# Epoch 2/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.4804 - accuracy: 1.0000 - val_loss: 0.2603 - val_accuracy: 0.8966
# Epoch 3/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.4360 - accuracy: 1.0000 - val_loss: 0.2373 - val_accuracy: 0.8966
# Epoch 4/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.3976 - accuracy: 1.0000 - val_loss: 0.2155 - val_accuracy: 0.9655
# Epoch 5/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.3609 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9655
# Epoch 6/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.3257 - accuracy: 1.0000 - val_loss: 0.1705 - val_accuracy: 0.9655
# Epoch 7/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.2922 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9655
# Epoch 8/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.2593 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9655
# Epoch 9/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.2258 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9655
# Epoch 10/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.1917 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 1.0000
# Epoch 11/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.1565 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 1.0000
# Epoch 12/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.1184 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0887 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 14/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0652 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 8.3205e-04 - val_accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 7.1012e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 6.2033e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 5.4866e-04 - val_accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 4.8636e-04 - val_accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 4.2978e-04 - val_accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.7821e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.3328e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.9564e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.6475e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.3993e-04 - val_accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.1996e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.0368e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.9033e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.7942e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.7040e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 27s 27s/step - loss: 9.6846e-04 - accuracy: 1.0000 - val_loss: 1.6277e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 27s 27s/step - loss: 8.9629e-04 - accuracy: 1.0000 - val_loss: 1.5623e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 27s 27s/step - loss: 8.3173e-04 - accuracy: 1.0000 - val_loss: 1.5056e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 27s 27s/step - loss: 7.7254e-04 - accuracy: 1.0000 - val_loss: 1.4555e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 27s 27s/step - loss: 7.2084e-04 - accuracy: 1.0000 - val_loss: 1.4116e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 27s 27s/step - loss: 6.7593e-04 - accuracy: 1.0000 - val_loss: 1.3725e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 27s 27s/step - loss: 6.3506e-04 - accuracy: 1.0000 - val_loss: 1.3383e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 27s 27s/step - loss: 5.9956e-04 - accuracy: 1.0000 - val_loss: 1.3079e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 27s 27s/step - loss: 5.6596e-04 - accuracy: 1.0000 - val_loss: 1.2806e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 27s 27s/step - loss: 5.3630e-04 - accuracy: 1.0000 - val_loss: 1.2564e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 27s 27s/step - loss: 5.1032e-04 - accuracy: 1.0000 - val_loss: 1.2349e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 27s 27s/step - loss: 4.8614e-04 - accuracy: 1.0000 - val_loss: 1.2151e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 27s 27s/step - loss: 4.6671e-04 - accuracy: 1.0000 - val_loss: 1.1972e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 27s 27s/step - loss: 4.5003e-04 - accuracy: 1.0000 - val_loss: 1.1813e-04 - val_accuracy: 1.0000

# %%
plot_history(history_new5)

# %%
model_new5.evaluate(test_ds_new5, return_dict=True)
# Out:
# 24/24 [==============================] - 16s 666ms/step - loss: 7.1924e-05 - accuracy: 1.0000
# {'loss': 7.192385237431154e-05, 'accuracy': 1.0}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test5/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new5, model_new5)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new5, model_new5)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 24/24 [==============================] - 16s 669ms/step

# %%
precision5, recall5 = calculate_classification_metrics(actual, predicted, labels) # Test dataset

# %%
precision5
# Out:
# {'IntCleaner': 1.0}

# %%
recall5
# Out:
# {'IntCleaner': 1.0}

# %% [markdown]
# # Background and Interactions(jolt + chase + TS + int)

# %% [markdown]
# **2 classes:**
# + Background
# + Intclient + intcleaner + ts + jolt + chase
#
# + learning_rate = 0.001
#
# Path: *Sep_Clips_Test3*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new3_1 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new3_1 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new3_1 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test3/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new3_1 = train_ds_new3_1.batch(batch_size)
val_ds_new3_1 = val_ds_new3_1.batch(batch_size)
test_ds_new3_1 = test_ds_new3_1.batch(batch_size)

# %%
model_new3_1 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new3_1))
model_new3_1.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new3_1, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new3_1.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0
py:25: RuntimeWarning: invalid value encountered in long_scalars
#   precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision

# %%
precision3_1
# Out:
# {'IntCleaner': 0.631578947368421, 'background': nan}

# %%
recall3_1
# Out:
# {'IntCleaner': 1.0, 'background': 0.0}

# %% [markdown]
# # Background and Interactions(jolt + chase + TS + int)

# %% [markdown]
# **2 classes:**
# + Background
# + Intclient + intcleaner + ts + jolt + chase
#
# + learning_rate = 0.01
#
# Path: *Sep_Clips_Test3*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new3_2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new3_2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new3_2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test3/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new3_2 = train_ds_new3_2.batch(batch_size)
val_ds_new3_2 = val_ds_new3_2.batch(batch_size)
test_ds_new3_2 = test_ds_new3_2.batch(batch_size)

# %%
model_new3_2 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new3_2))
model_new3_2.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new3_2, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new3_2.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.01), 
              metrics = ['accuracy'])

# %%
history_new3_2 = model_new3_2.fit(x = train_ds_new3_2, epochs = 50, validation_data = val_ds_new3_1)
# Out:
# Epoch 1/50
# 117/117 [==============================] - 236s 2s/step - loss: 0.9264 - accuracy: 0.5726 - val_loss: 0.8335 - val_accuracy: 0.3409
# Epoch 2/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.7164 - accuracy: 0.5470 - val_loss: 0.6521 - val_accuracy: 0.6591
# Epoch 3/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6974 - accuracy: 0.6154 - val_loss: 0.6808 - val_accuracy: 0.6591
# Epoch 4/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.7021 - accuracy: 0.6325 - val_loss: 0.6476 - val_accuracy: 0.6591
# Epoch 5/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6926 - accuracy: 0.6154 - val_loss: 0.6466 - val_accuracy: 0.6591
# Epoch 6/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6673 - accuracy: 0.6410 - val_loss: 0.6431 - val_accuracy: 0.6591
# Epoch 7/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6929 - accuracy: 0.5983 - val_loss: 0.6767 - val_accuracy: 0.6591
# Epoch 8/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.7066 - accuracy: 0.5897 - val_loss: 0.6470 - val_accuracy: 0.6591
# Epoch 9/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6695 - accuracy: 0.6410 - val_loss: 0.6427 - val_accuracy: 0.6591
# Epoch 10/50
# 117/117 [==============================] - 246s 2s/step - loss: 0.7129 - accuracy: 0.5983 - val_loss: 0.6620 - val_accuracy: 0.6591
# Epoch 11/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6779 - accuracy: 0.6239 - val_loss: 0.6426 - val_accuracy: 0.6591
# Epoch 12/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6827 - accuracy: 0.6410 - val_loss: 0.6418 - val_accuracy: 0.6591
# Epoch 13/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6660 - accuracy: 0.6410 - val_loss: 0.6443 - val_accuracy: 0.6591
# Epoch 14/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6955 - accuracy: 0.6410 - val_loss: 0.6457 - val_accuracy: 0.6591
# Epoch 15/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6804 - accuracy: 0.6410 - val_loss: 0.6433 - val_accuracy: 0.6591
# Epoch 16/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6920 - accuracy: 0.6154 - val_loss: 0.6449 - val_accuracy: 0.6591
# Epoch 17/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6983 - accuracy: 0.5726 - val_loss: 0.6424 - val_accuracy: 0.6591
# Epoch 18/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.7549 - accuracy: 0.5641 - val_loss: 0.6421 - val_accuracy: 0.6591
# Epoch 19/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6613 - accuracy: 0.6410 - val_loss: 0.6419 - val_accuracy: 0.6591
# Epoch 20/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6602 - accuracy: 0.6410 - val_loss: 0.6422 - val_accuracy: 0.6591
# Epoch 21/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6401 - accuracy: 0.6154 - val_loss: 1.0851 - val_accuracy: 0.6591
# Epoch 22/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6780 - accuracy: 0.6410 - val_loss: 0.6438 - val_accuracy: 0.6591
# Epoch 23/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6601 - accuracy: 0.6410 - val_loss: 0.6418 - val_accuracy: 0.6591
# Epoch 24/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6571 - accuracy: 0.6410 - val_loss: 0.6440 - val_accuracy: 0.6591
# Epoch 25/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6654 - accuracy: 0.6239 - val_loss: 0.6444 - val_accuracy: 0.6591
# Epoch 26/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6825 - accuracy: 0.6154 - val_loss: 0.6430 - val_accuracy: 0.6591
# Epoch 27/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6722 - accuracy: 0.6410 - val_loss: 0.6421 - val_accuracy: 0.6591
# Epoch 28/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6599 - accuracy: 0.6410 - val_loss: 0.6417 - val_accuracy: 0.6591
# Epoch 29/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6535 - accuracy: 0.6410 - val_loss: 0.6794 - val_accuracy: 0.6591
# Epoch 30/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.7145 - accuracy: 0.6410 - val_loss: 0.9578 - val_accuracy: 0.6591
# Epoch 31/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.7092 - accuracy: 0.6239 - val_loss: 0.6434 - val_accuracy: 0.6591
# Epoch 32/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6750 - accuracy: 0.5726 - val_loss: 0.6561 - val_accuracy: 0.6591
# Epoch 33/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6868 - accuracy: 0.6410 - val_loss: 0.6471 - val_accuracy: 0.6591
# Epoch 34/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6643 - accuracy: 0.6410 - val_loss: 0.6470 - val_accuracy: 0.6591
# Epoch 35/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6624 - accuracy: 0.6410 - val_loss: 0.6447 - val_accuracy: 0.6591
# Epoch 36/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6592 - accuracy: 0.6410 - val_loss: 0.6428 - val_accuracy: 0.6591
# Epoch 37/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6740 - accuracy: 0.6325 - val_loss: 0.6811 - val_accuracy: 0.6591
# Epoch 38/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.7708 - accuracy: 0.6154 - val_loss: 0.6497 - val_accuracy: 0.6591
# Epoch 39/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6873 - accuracy: 0.6239 - val_loss: 0.6418 - val_accuracy: 0.6591
# Epoch 40/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6731 - accuracy: 0.6239 - val_loss: 0.6424 - val_accuracy: 0.6591
# Epoch 41/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.8165 - accuracy: 0.6325 - val_loss: 0.6418 - val_accuracy: 0.6591
# Epoch 42/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6709 - accuracy: 0.6325 - val_loss: 0.6425 - val_accuracy: 0.6591
# Epoch 43/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6553 - accuracy: 0.6410 - val_loss: 0.6429 - val_accuracy: 0.6591
# Epoch 44/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6615 - accuracy: 0.6410 - val_loss: 0.6474 - val_accuracy: 0.6591
# Epoch 45/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6740 - accuracy: 0.5983 - val_loss: 0.6421 - val_accuracy: 0.6591
# Epoch 46/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6626 - accuracy: 0.6410 - val_loss: 0.6430 - val_accuracy: 0.6591
# Epoch 47/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6850 - accuracy: 0.6410 - val_loss: 0.6517 - val_accuracy: 0.6591
# Epoch 48/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6718 - accuracy: 0.6410 - val_loss: 0.6417 - val_accuracy: 0.6591
# Epoch 49/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6597 - accuracy: 0.6410 - val_loss: 0.6437 - val_accuracy: 0.6591
# Epoch 50/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6568 - accuracy: 0.6410 - val_loss: 0.6425 - val_accuracy: 0.6591

# %%
plot_history(history_new3_2)

# %%
model_new3_2.evaluate(test_ds_new3_2, return_dict=True)
# Out:
# 38/38 [==============================] - 35s 910ms/step - loss: 0.6583 - accuracy: 0.6316
# {'loss': 0.658255398273468, 'accuracy': 0.6315789222717285}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new3_2, model_new3_2)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 125s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new3_2, model_new3_2)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 35s 908ms/step

# %%
precision3_2, recall3_2 = calculate_classification_metrics(actual, predicted, labels) # Test dataset
# Out:
# C:\Users\BEE Team\AppData\Local\Temp\ipykernel_13864\3092751621.py:25: RuntimeWarning: invalid value encountered in long_scalars
#   precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision

# %%
precision3_2
# Out:
# {'IntCleaner': 0.631578947368421, 'background': nan}

# %%
recall3_2
# Out:
# {'IntCleaner': 1.0, 'background': 0.0}
