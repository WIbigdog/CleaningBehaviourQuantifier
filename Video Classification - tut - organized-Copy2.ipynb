# %% [markdown]
# **Table of Contents:**
# <br> **1- Video classification**
# + Imports
# + Classes
# + Functions
# + Model Structure
# + Model Stucture
# + Checking Frames
#
# <br> **2- Data with everything**
# <br> **3- Data joined interactions and jolt+run**
# <br> **4- Int and background**
# <br> **5- Background and Interactions(jolt+chase+TS+Ints)**
# <br> **6- Training with one video**
# <br> **7- Background and Interactions(jolt+chase+TS+Ints) lr=0.001**
# <br> **8- Background and Interactions(jolt+chase+TS+Ints) lr=0.01**

# %% [markdown]
# # Video Classification
# https://www.tensorflow.org/tutorials/video/video_classification

# %% [markdown]
# ## Imports

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.11.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\users\public\new\envs\tensorflowraul\lib\site-packages
# Requires: tensorflow-intel
# Required-by:
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\bee team\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\public\new\envs\tensorflowraul\lib\site-packages)

# %%
import tqdm
import random
import pathlib
import itertools
import collections

import cv2
import einops
import numpy as np
import remotezip as rz
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers

from pathlib import Path

# %%
# Set the seed for Python's random number generator
random.seed(1999)

# Set the seed for NumPy's random number generator
np.random.seed(1999)

# Set the seed for TensorFlow's random number generator
tf.random.set_seed(1999)

# %% [markdown]
# ## Classes:

# %%
class FrameGenerator:
  def __init__(self, path, n_frames, training = False):
    """ Returns a set of frames with their associated label. 

      Args:
        path: Video file paths.
        n_frames: Number of frames. 
        training: Boolean to determine if training dataset is being created.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.mp4'))
    classes = [p.parent.name for p in video_paths] 
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path, self.n_frames) 
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %%
class Conv2Plus1D(keras.layers.Layer):
  def __init__(self, filters, kernel_size, padding):
    """
      A sequence of convolutional layers that first apply the convolution operation over the
      spatial dimensions, and then the temporal dimension. 
    """
    super().__init__()
    self.seq = keras.Sequential([  
        # Spatial decomposition
        layers.Conv3D(filters=filters,
                      kernel_size=(1, kernel_size[1], kernel_size[2]),
                      padding=padding),
        # Temporal decomposition
        layers.Conv3D(filters=filters, 
                      kernel_size=(kernel_size[0], 1, 1),
                      padding=padding)
        ])

  def call(self, x):
    return self.seq(x)

# %%
class ResidualMain(keras.layers.Layer):
  """
    Residual block of the model with convolution, layer normalization, and the
    activation function, ReLU.
  """
  def __init__(self, filters, kernel_size):
    super().__init__()
    self.seq = keras.Sequential([
        Conv2Plus1D(filters=filters,
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization(),
        layers.ReLU(),
        Conv2Plus1D(filters=filters, 
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %%
class Project(keras.layers.Layer):
  """
    Project certain dimensions of the tensor as the data is passed through different 
    sized filters and downsampled. 
  """
  def __init__(self, units):
    super().__init__()
    self.seq = keras.Sequential([
        layers.Dense(units),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %%
class ResizeVideo(keras.layers.Layer):
  def __init__(self, height, width):
    super().__init__()
    self.height = height
    self.width = width
    self.resizing_layer = layers.Resizing(self.height, self.width)

  def call(self, video):
    """
      Use the einops library to resize the tensor.  

      Args:
        video: Tensor representation of the video, in the form of a set of frames.

      Return:
        A downsampled size of the video according to the new height and width it should be resized to.
    """
    # b stands for batch size, t stands for time, h stands for height, 
    # w stands for width, and c stands for the number of channels.
    old_shape = einops.parse_shape(video, 'b t h w c')
    images = einops.rearrange(video, 'b t h w c -> (b t) h w c')
    images = self.resizing_layer(images)
    videos = einops.rearrange(
        images, '(b t) h w c -> b t h w c',
        t = old_shape['t'])
    return videos

# %% [markdown]
# ## Functions

# %%
def frames_from_video_file(video_path, n_frames, output_size = (224,224), frame_step = 60):
  """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
  """
  # Read each video frame by frame
  result = []
  src = cv2.VideoCapture(str(video_path))  

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frames(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frames(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

# %%
def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.

    Args:
      frame: Image that needs to resized and padded. 
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

# %%
def add_residual_block(input, filters, kernel_size):
  """
    Add residual blocks to the model. If the last dimensions of the input data
    and filter size does not match, project it such that last dimension matches.
  """
  out = ResidualMain(filters, 
                     kernel_size)(input)

  res = input
  # Using the Keras functional APIs, project the last dimension of the tensor to
  # match the new filter size
  if out.shape[-1] != input.shape[-1]:
    res = Project(out.shape[-1])(res)

  return layers.add([res, out])

# %%
def plot_history(history):
  """
    Plotting training and validation learning curves.

    Args:
      history: model history with all the metric measures
  """
  fig, (ax1, ax2) = plt.subplots(2)

  fig.set_size_inches(18.5, 10.5)

  # Plot loss
  ax1.set_title('Loss')
  ax1.plot(history.history['loss'], label = 'train')
  ax1.plot(history.history['val_loss'], label = 'test')
  ax1.set_ylabel('Loss')

  # Determine upper bound of y-axis
  max_loss = max(history.history['loss'] + history.history['val_loss'])

  ax1.set_ylim([0, np.ceil(max_loss)])
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation']) 

  # Plot accuracy
  ax2.set_title('Accuracy')
  ax2.plot(history.history['accuracy'],  label = 'train')
  ax2.plot(history.history['val_accuracy'], label = 'test')
  ax2.set_ylabel('Accuracy')
  ax2.set_ylim([0, 1])
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'])

  plt.show()

# %%
### added model to the input
def get_actual_predicted_labels(dataset, model): 
  """
    Create a list of actual ground truth values and the predictions from the model.

    Args:
      dataset: An iterable data structure, such as a TensorFlow Dataset, with features and labels.

    Return:
      Ground truth and predicted values for a particular dataset.
  """
  actual = [labels for _, labels in dataset.unbatch()]
  predicted = model.predict(dataset)

  actual = tf.stack(actual, axis=0)
  predicted = tf.concat(predicted, axis=0)
  predicted = tf.argmax(predicted, axis=1)

  return actual, predicted

# %%
def plot_confusion_matrix(actual, predicted, labels, ds_type):
  cm = tf.math.confusion_matrix(actual, predicted)
  ax = sns.heatmap(cm, annot=True, fmt='g')
  sns.set(rc={'figure.figsize':(12, 12)})
  sns.set(font_scale=1.4)
  ax.set_title('Confusion matrix of action recognition for ' + ds_type)
  ax.set_xlabel('Predicted Action')
  ax.set_ylabel('Actual Action')
  plt.xticks(rotation=90)
  plt.yticks(rotation=0)
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %%
def calculate_classification_metrics(y_actual, y_pred, labels):
  """
    Calculate the precision and recall of a classification model using the ground truth and
    predicted values. 

    Args:
      y_actual: Ground truth labels.
      y_pred: Predicted labels.
      labels: List of classification labels.

    Return:
      Precision and recall measures.
  """
  cm = tf.math.confusion_matrix(y_actual, y_pred)
  tp = np.diag(cm) # Diagonal represents true positives
  precision = dict()
  recall = dict()
  for i in range(len(labels)):
    col = cm[:, i]
    fp = np.sum(col) - tp[i] # Sum of column minus true positive is false negative

    row = cm[i, :]
    fn = np.sum(row) - tp[i] # Sum of row minus true positive, is false negative

    precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision 

    recall[labels[i]] = tp[i] / (tp[i] + fn) # Recall

  return precision, recall

# %% [markdown]
# ## Model structure

# %%
# Define the dimensions of one frame in the set of frames created
HEIGHT = 224
WIDTH = 224

# %%
input_shape = (None, 10, HEIGHT, WIDTH, 3)
input = layers.Input(shape=(input_shape[1:]))
x = input

x = Conv2Plus1D(filters=16, kernel_size=(3, 7, 7), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = ResizeVideo(HEIGHT // 2, WIDTH // 2)(x)

# Block 1
x = add_residual_block(x, 16, (3, 3, 3))
x = ResizeVideo(HEIGHT // 4, WIDTH // 4)(x)

# Block 2
x = add_residual_block(x, 32, (3, 3, 3))
x = ResizeVideo(HEIGHT // 8, WIDTH // 8)(x)

# Block 3
x = add_residual_block(x, 64, (3, 3, 3))
x = ResizeVideo(HEIGHT // 16, WIDTH // 16)(x)

# Block 4
x = add_residual_block(x, 128, (3, 3, 3))

x = layers.GlobalAveragePooling3D()(x)
x = layers.Flatten()(x)
x = layers.Dense(10)(x)

# %% [markdown]
# ## Checking frames

# %%
import cv2
import os

# Path to the main folder containing subdirectories with videos
main_folder_path = r"C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test"

# Loop through all subdirectories inside the main folder
for root, dirs, files in os.walk(main_folder_path):
    for dir in dirs:
        sub_folder_path = os.path.join(root, dir)

        # Loop through all video files inside the subdirectory
        for filename in os.listdir(sub_folder_path):
            if filename.endswith(".mp4") or filename.endswith(".avi"):
                # Open the video file
                video = cv2.VideoCapture(os.path.join(sub_folder_path, filename))

                # Get the total number of frames
                total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

                print(f"Number of frames in {os.path.join(sub_folder_path, filename)}: {total_frames}")

                # Release the video object
                video.release()
# Out:
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_13.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_31.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_33.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_34.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_49.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_52.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_54.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_60.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_67.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_69.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_7.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_72.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_73.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\background\background_8.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntCleaner_4.mp4: 45
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntCleaner_6.mp4: 19
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntCleaner_8_1.mp4: 54
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_15.mp4: 32
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_17_1.mp4: 17
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_19.mp4: 15
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_1_3.mp4: 53
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_2.mp4: 65
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_22_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_26.mp4: 49
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_27.mp4: 73
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_28_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_32_1.mp4: 18
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_41.mp4: 51
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_43.mp4: 38
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_44.mp4: 42
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_50.mp4: 43
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\IntCleaner\IntClient_9_2.mp4: 23
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\Jolt\Jolt_12.mp4: 15
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\Jolt\Jolt_4.mp4: 39
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\Jolt\Jolt_5.mp4: 16
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\TS\TS_6_1.mp4: 44
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\TS\TS_8_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\test\TS\TS_8_3.mp4: 32

# %%
# Path to the main folder containing subdirectories with videos
main_folder_path = r"C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train"

# Loop through all subdirectories inside the main folder
for root, dirs, files in os.walk(main_folder_path):
    for dir in dirs:
        sub_folder_path = os.path.join(root, dir)

        # Loop through all video files inside the subdirectory
        for filename in os.listdir(sub_folder_path):
            if filename.endswith(".mp4"):
                # Open the video file
                video = cv2.VideoCapture(os.path.join(sub_folder_path, filename))

                # Get the total number of frames
                total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

                print(f"Number of frames in {os.path.join(sub_folder_path, filename)}: {total_frames}")

                # Release the video object
                video.release()
# Out:
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_10.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_11.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_12.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_17.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_18.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_19.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_2.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_21.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_22.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_24.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_27.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_28.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_3.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_30.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_32.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_35.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_37.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_38.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_39.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_41.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_42.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_43.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_44.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_45.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_46.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_48.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_50.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_51.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_53.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_55.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_56.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_57.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_61.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_62.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_64.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_66.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_68.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_70.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_74.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\background\background_9.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntCleaner_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntCleaner_1.mp4: 108
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntCleaner_11_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntCleaner_11_1.mp4: 67
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntCleaner_2.mp4: 48
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntCleaner_3.mp4: 41
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntCleaner_5_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntCleaner_5_1.mp4: 23
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntCleaner_7.mp4: 20
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_0_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_0_1.mp4: 115
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_10_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_11.mp4: 58
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_12.mp4: 108
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_13.mp4: 82
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_17_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_18_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_18_2.mp4: 74
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_1_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_1_2.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_20.mp4: 67
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_21.mp4: 27
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_22_1.mp4: 117
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_23.mp4: 90
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_24_1.mp4: 81
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_25.mp4: 44
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_28_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_28_2.mp4: 102
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_29.mp4: 46
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_30.mp4: 22
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_31.mp4: 90
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_32_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_33.mp4: 64
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_34.mp4: 98
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_35.mp4: 45
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_36.mp4: 24
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_37.mp4: 80
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_38.mp4: 14
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_39.mp4: 23
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_4.mp4: 31
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_40.mp4: 71
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_42.mp4: 36
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_46.mp4: 58
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_47.mp4: 86
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_48.mp4: 111
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_51_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_51_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_6_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_6_1.mp4: 19
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_7_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_7_2.mp4: 69
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_8.mp4: 94
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\IntCleaner\IntClient_9_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_0.mp4: 34
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_1.mp4: 24
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_11.mp4: 25
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_13.mp4: 28
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_16.mp4: 26
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_17.mp4: 17
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_18.mp4: 20
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_2.mp4: 31
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_3.mp4: 19
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_8.mp4: 22
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Jolt_9.mp4: 16
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\Jolt\Run_0_1.mp4: 24
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_0.mp4: 25
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_10.mp4: 61
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_1_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_1_1.mp4: 17
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_2.mp4: 32
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_3_1.mp4: 61
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_4.mp4: 114
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_7_0.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_8_1.mp4: 120
# Number of frames in C:\Users\BEE Team\Desktop\code\Summarys_labels\Sep_Clips_Test\train\TS\TS_8_2.mp4: 120

# %% [markdown]
# # Data with everything

# %% [markdown]
# **6 classes:**
# + Background
# + Intcleaner
# + intclient
# + TS
# + Jolt
# + Chase
#
# Path: *Sep_Clips*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)

# %%
model = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds))
model.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history = model.fit(x = train_ds, epochs = 50, validation_data = val_ds)
# Out:
# Epoch 1/50
# 117/117 [==============================] - 253s 2s/step - loss: 1.7395 - accuracy: 0.3932 - val_loss: 1.5029 - val_accuracy: 0.5227
# Epoch 2/50
# 117/117 [==============================] - 237s 2s/step - loss: 1.5581 - accuracy: 0.3248 - val_loss: 1.4687 - val_accuracy: 0.3409
# Epoch 3/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.3840 - accuracy: 0.4103 - val_loss: 1.5392 - val_accuracy: 0.3409
# Epoch 4/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.4237 - accuracy: 0.4530 - val_loss: 1.6307 - val_accuracy: 0.5227
# Epoch 5/50
# 117/117 [==============================] - 236s 2s/step - loss: 1.3726 - accuracy: 0.4017 - val_loss: 1.3647 - val_accuracy: 0.5227
# Epoch 6/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.3065 - accuracy: 0.4530 - val_loss: 1.3221 - val_accuracy: 0.5227
# Epoch 7/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.3812 - accuracy: 0.4017 - val_loss: 1.4553 - val_accuracy: 0.5227
# Epoch 8/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.3504 - accuracy: 0.4615 - val_loss: 1.4706 - val_accuracy: 0.3409
# Epoch 9/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.3303 - accuracy: 0.3504 - val_loss: 1.3417 - val_accuracy: 0.4773
# Epoch 10/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.2691 - accuracy: 0.4274 - val_loss: 1.4385 - val_accuracy: 0.3409
# Epoch 11/50
# 117/117 [==============================] - 236s 2s/step - loss: 1.3240 - accuracy: 0.4103 - val_loss: 1.4326 - val_accuracy: 0.3409
# Epoch 12/50
# 117/117 [==============================] - 237s 2s/step - loss: 1.2708 - accuracy: 0.4017 - val_loss: 1.6017 - val_accuracy: 0.3409
# Epoch 13/50
# 117/117 [==============================] - 236s 2s/step - loss: 1.2269 - accuracy: 0.4786 - val_loss: 1.5288 - val_accuracy: 0.3409
# Epoch 14/50
# 117/117 [==============================] - 237s 2s/step - loss: 1.2911 - accuracy: 0.4444 - val_loss: 1.3141 - val_accuracy: 0.5227
# Epoch 15/50
# 117/117 [==============================] - 236s 2s/step - loss: 1.3010 - accuracy: 0.4359 - val_loss: 1.3619 - val_accuracy: 0.3409
# Epoch 16/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.2676 - accuracy: 0.4359 - val_loss: 1.3908 - val_accuracy: 0.5227
# Epoch 17/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.2594 - accuracy: 0.3932 - val_loss: 1.4345 - val_accuracy: 0.5227
# Epoch 18/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.2365 - accuracy: 0.4188 - val_loss: 1.6502 - val_accuracy: 0.5227
# Epoch 19/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.3013 - accuracy: 0.4444 - val_loss: 1.3635 - val_accuracy: 0.3182
# Epoch 20/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.
50
# 117/117 [==============================] - 235s 2s/step - loss: 1.2529 - accuracy: 0.4017 - val_loss: 1.3972 - val_accuracy: 0.5227

# %%
plot_history(history)

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 38/38 [==============================] - 36s 920ms/step - loss: 2.1058 - accuracy: 0.2895
# {'loss': 2.105769395828247, 'accuracy': 0.28947368264198303}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds, model)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 125s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds, model)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 35s 900ms/step

# %%
precision, recall = calculate_classification_metrics(actual, predicted, labels) # Test dataset
# Out:
# C:\Users\BEE Team\AppData\Local\Temp\ipykernel_5988\3092751621.py:25: RuntimeWarning: invalid value encountered in long_scalars
#   precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision
# C:\Users\BEE Team\AppData\Local\Temp\ipykernel_5988\3092751621.py:27: RuntimeWarning: invalid value encountered in long_scalars
#   recall[labels[i]] = tp[i] / (tp[i] + fn) # Recall

# %%
precision
# Out:
# {'IntCleaner': nan,
#  'IntClient': 0.5789473684210527,
#  'Jolt': nan,
#  'Run': nan,
#  'TS': nan,
#  'background': 0.0}

# %%
recall
# Out:
# {'IntCleaner': 0.0,
#  'IntClient': 0.7333333333333333,
#  'Jolt': 0.0,
#  'Run': 0.0,
#  'TS': 0.0,
#  'background': nan}

# %% [markdown]
# # Data joined interactions and jolt+run

# %% [markdown]
# **4 classes:**
# + Background
# + Intcleaner + intclient
# + TS
# + Jolt + Chase
#
# Path: *Sep_Clips_Test*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new = train_ds_new.batch(batch_size)
val_ds_new = val_ds_new.batch(batch_size)
test_ds_new = test_ds_new.batch(batch_size)

# %%
model_new = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new))
model_new.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history_new = model_new.fit(x = train_ds_new, epochs = 50, validation_data = val_ds_new)
# Out:
# Epoch 1/50
# 117/117 [==============================] - 239s 2s/step - loss: 1.4451 - accuracy: 0.3761 - val_loss: 1.2559 - val_accuracy: 0.5682
# Epoch 2/50
# 117/117 [==============================] - 236s 2s/step - loss: 1.0724 - accuracy: 0.4957 - val_loss: 1.3083 - val_accuracy: 0.4091
# Epoch 3/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.0049 - accuracy: 0.4359 - val_loss: 1.3043 - val_accuracy: 0.4091
# Epoch 4/50
# 117/117 [==============================] - 236s 2s/step - loss: 1.0399 - accuracy: 0.4274 - val_loss: 1.3745 - val_accuracy: 0.4091
# Epoch 5/50
# 117/117 [==============================] - 236s 2s/step - loss: 0.9995 - accuracy: 0.4188 - val_loss: 1.4821 - val_accuracy: 0.5682
# Epoch 6/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.9879 - accuracy: 0.4615 - val_loss: 1.6555 - val_accuracy: 0.3409
# Epoch 7/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.0108 - accuracy: 0.4701 - val_loss: 1.4420 - val_accuracy: 0.4773
# Epoch 8/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.0194 - accuracy: 0.4103 - val_loss: 1.4280 - val_accuracy: 0.4091
# Epoch 9/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.0410 - accuracy: 0.4274 - val_loss: 1.4586 - val_accuracy: 0.5682
# Epoch 10/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.0002 - accuracy: 0.4359 - val_loss: 1.4440 - val_accuracy: 0.4091
# Epoch 11/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9911 - accuracy: 0.4615 - val_loss: 1.3765 - val_accuracy: 0.4091
# Epoch 12/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.0287 - accuracy: 0.4530 - val_loss: 1.3622 - val_accuracy: 0.5682
# Epoch 13/50
# 117/117 [==============================] - 233s 2s/step - loss: 1.0012 - accuracy: 0.4701 - val_loss: 1.4352 - val_accuracy: 0.5682
# Epoch 14/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9753 - accuracy: 0.4530 - val_loss: 1.4945 - val_accuracy: 0.5682
# Epoch 15/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9997 - accuracy: 0.4615 - val_loss: 1.5298 - val_accuracy: 0.3864
# Epoch 16/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9874 - accuracy: 0.4017 - val_loss: 1.4502 - val_accuracy: 0.5682
# Epoch 17/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.
50
# 117/117 [==============================] - 235s 2s/step - loss: 0.9535 - accuracy: 0.4615 - val_loss: 1.6018 - val_accuracy: 0.4318
# Epoch 48/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.9459 - accuracy: 0.4872 - val_loss: 1.6278 - val_accuracy: 0.4773
# Epoch 49/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.9359 - accuracy: 0.5214 - val_loss: 1.5213 - val_accuracy: 0.4091
# Epoch 50/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.9287 - accuracy: 0.4957 - val_loss: 1.5724 - val_accuracy: 0.4318

# %%
plot_history(history_new)

# %%
model_new.evaluate(test_ds_new, return_dict=True)
# Out:
# 38/38 [==============================] - 35s 918ms/step - loss: 1.1891 - accuracy: 0.7368
# {'loss': 1.1891305446624756, 'accuracy': 0.7368420958518982}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new, model_new)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 125s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new, model_new)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 35s 907ms/step

# %% [markdown]
# # Int and Background

# %% [markdown]
# **2 classes:**
# + Background
# + Intcleaner + intclient
#
# Path: *Sep_Clips_Test2*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test2/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new2 = train_ds_new2.batch(batch_size)
val_ds_new2 = val_ds_new2.batch(batch_size)
test_ds_new2 = test_ds_new2.batch(batch_size)

# %%
model_new2 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new2))
model_new2.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new2, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new2.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history_new2 = model_new2.fit(x = train_ds_new2, epochs = 50, validation_data = val_ds_new2)
# Out:
# Epoch 1/50
# 95/95 [==============================] - 201s 2s/step - loss: 1.0787 - accuracy: 0.4632 - val_loss: 0.6063 - val_accuracy: 0.5758
# Epoch 2/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.6424 - accuracy: 0.5158 - val_loss: 0.6017 - val_accuracy: 0.5455
# Epoch 3/50
# 95/95 [==============================] - 198s 2s/step - loss: 0.6186 - accuracy: 0.6105 - val_loss: 0.5508 - val_accuracy: 0.5455
# Epoch 4/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5995 - accuracy: 0.6105 - val_loss: 0.5709 - val_accuracy: 0.5455
# Epoch 5/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.6223 - accuracy: 0.5263 - val_loss: 0.5480 - val_accuracy: 0.5152
# Epoch 6/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.6088 - accuracy: 0.5684 - val_loss: 0.5542 - val_accuracy: 0.5455
# Epoch 7/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.6247 - accuracy: 0.5789 - val_loss: 0.5188 - val_accuracy: 0.5758
# Epoch 8/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5953 - accuracy: 0.5684 - val_loss: 0.5084 - val_accuracy: 0.7576
# Epoch 9/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.6031 - accuracy: 0.6316 - val_loss: 0.5117 - val_accuracy: 0.5758
# Epoch 10/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.6136 - accuracy: 0.5789 - val_loss: 0.5641 - val_accuracy: 0.5455
# Epoch 11/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5820 - accuracy: 0.6105 - val_loss: 0.4983 - val_accuracy: 0.7576
# Epoch 12/50
# 95/95 [==============================] - 198s 2s/step - loss: 0.5863 - accuracy: 0.6000 - val_loss: 0.5037 - val_accuracy: 0.5758
# Epoch 13/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5864 - accuracy: 0.5789 - val_loss: 0.5018 - val_accuracy: 0.7273
# Epoch 14/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5930 - accuracy: 0.5789 - val_loss: 0.5013 - val_accuracy: 0.7273
# Epoch 15/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5763 - accuracy: 0.6105 - val_loss: 0.5071 - val_accuracy: 0.5758
# Epoch 16/50
# 95/95 [==============================] - 198s 2s/step - loss: 0.5728 - accuracy: 0.6421 - val_loss: 0.4965 - val_accuracy: 0.7576
# Epoch 17/50
# 95/95 [==============================] - 198s 2s/step - loss: 0.5840 - accuracy: 0.6105 - val_loss: 0.5116 - val_accuracy: 0.5758
# Epoch 18/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5826 - accuracy: 0.6000 - val_loss: 0.5728 - val_accuracy: 0.5455
# Epoch 19/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.5921 - accuracy: 0.6211 - val_loss: 0.5547 - val_accuracy: 0.5758
# Epoch 20/50
# 95/95 [==============================] - 197s 2s/step - loss: 0.
50
# 95/95 [==============================] - 198s 2s/step - loss: 0.5734 - accuracy: 0.6421 - val_loss: 0.5406 - val_accuracy: 0.5455
# Epoch 50/50
# 95/95 [==============================] - 198s 2s/step - loss: 0.5810 - accuracy: 0.6105 - val_loss: 0.5620 - val_accuracy: 0.5455

# %%
plot_history(history_new2)

# %%
model_new2.evaluate(test_ds_new2, return_dict=True)
# Out:
# 32/32 [==============================] - 31s 962ms/step - loss: 0.4167 - accuracy: 0.5625
# {'loss': 0.4167194366455078, 'accuracy': 0.5625}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test2/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new2, model_new2)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 95/95 [==============================] - 110s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new2, model_new2)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 32/32 [==============================] - 31s 961ms/step

# %% [markdown]
# # Background and Interactions(jolt + chase + TS + int)

# %% [markdown]
# **2 classes:**
# + Background
# + Intclient + intcleaner + ts + jolt + chase
#
# Path: *Sep_Clips_Test3*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new3 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new3 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new3 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test3/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new3 = train_ds_new3.batch(batch_size)
val_ds_new3 = val_ds_new3.batch(batch_size)
test_ds_new3 = test_ds_new3.batch(batch_size)

# %%
model_new3 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new3))
model_new3.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new3, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new3.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history_new3 = model_new3.fit(x = train_ds_new3, epochs = 50, validation_data = val_ds_new3)
# Out:
# Epoch 1/50
# 117/117 [==============================] - 240s 2s/step - loss: 0.5296 - accuracy: 0.6154 - val_loss: 0.4847 - val_accuracy: 0.6591
# Epoch 2/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5209 - accuracy: 0.6581 - val_loss: 0.5076 - val_accuracy: 0.6591
# Epoch 3/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.5108 - accuracy: 0.6325 - val_loss: 0.4724 - val_accuracy: 0.5909
# Epoch 4/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.5154 - accuracy: 0.6838 - val_loss: 0.4869 - val_accuracy: 0.6591
# Epoch 5/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.5265 - accuracy: 0.6239 - val_loss: 0.4785 - val_accuracy: 0.5909
# Epoch 6/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.5252 - accuracy: 0.6239 - val_loss: 0.4840 - val_accuracy: 0.6591
# Epoch 7/50
# 117/117 [==============================] - 237s 2s/step - loss: 0.5168 - accuracy: 0.5983 - val_loss: 0.4772 - val_accuracy: 0.5909
# Epoch 8/50
# 117/117 [==============================] - 248s 2s/step - loss: 0.5130 - accuracy: 0.6496 - val_loss: 0.4587 - val_accuracy: 0.6591
# Epoch 9/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5115 - accuracy: 0.6496 - val_loss: 0.5131 - val_accuracy: 0.6591
# Epoch 10/50
# 117/117 [==============================] - 238s 2s/step - loss: 0.5210 - accuracy: 0.6496 - val_loss: 0.4680 - val_accuracy: 0.5909
# Epoch 11/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5224 - accuracy: 0.5983 - val_loss: 0.4707 - val_accuracy: 0.7045
# Epoch 12/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5193 - accuracy: 0.6496 - val_loss: 0.4661 - val_accuracy: 0.5909
# Epoch 13/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5204 - accuracy: 0.6068 - val_loss: 0.4692 - val_accuracy: 0.5909
# Epoch 14/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5108 - accuracy: 0.6923 - val_loss: 0.4681 - val_accuracy: 0.5909
# Epoch 15/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5048 - accuracy: 0.6667 - val_loss: 0.4807 - val_accuracy: 0.6591
# Epoch 16/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5173 - accuracy: 0.6752 - val_loss: 0.4715 - val_accuracy: 0.7045
# Epoch 17/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.5094 - accuracy: 0.6410 - val_loss: 0.4724 - val_accuracy: 0.5909
# Epoch 18/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5058 - accuracy: 0.6581 - val_loss: 0.4706 - val_accuracy: 0.5909
# Epoch 19/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.5025 - accuracy: 0.6581 - val_loss: 0.4918 - val_accuracy: 0.6591
# Epoch 20/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.
50
# 117/117 [==============================] - 235s 2s/step - loss: 0.5070 - accuracy: 0.6581 - val_loss: 0.4667 - val_accuracy: 0.5909

# %%
plot_history(history_new3)

# %%
model_new3.evaluate(test_ds_new3, return_dict=True)
# Out:
# 38/38 [==============================] - 36s 923ms/step - loss: 0.3440 - accuracy: 0.8684
# {'loss': 0.3439883291721344, 'accuracy': 0.8684210777282715}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new3, model_new3)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 127s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new3, model_new3)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 35s 917ms/step

# %%
precision_3, recall_3 = calculate_classification_metrics(actual, predicted, labels) # Test dataset

# %%
precision_3
# Out:
# {'IntCleaner': 0.88, 'background': 0.8461538461538461}

# %%
recall_3
# Out:
# {'IntCleaner': 0.9166666666666666, 'background': 0.7857142857142857}

# %% [markdown]
# # Training with one video (?)

# %% [markdown]
# + **1 class** with 1 video in trainning:
#
# Path: *Sep_Clips_Test5*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new5 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test5/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new5 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test5/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new5 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test5/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new5 = train_ds_new5.batch(batch_size)
val_ds_new5 = val_ds_new5.batch(batch_size)
test_ds_new5 = test_ds_new5.batch(batch_size)

# %%
model_new5 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new5))
model_new5.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new5, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new5.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history_new5 = model_new5.fit(x = train_ds_new5, epochs = 50, validation_data = val_ds_new5)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 31s 31s/step - loss: 0.7447 - accuracy: 0.0000e+00 - val_loss: 0.3097 - val_accuracy: 0.8966
# Epoch 2/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.6948 - accuracy: 0.0000e+00 - val_loss: 0.2874 - val_accuracy: 0.9655
# Epoch 3/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.6485 - accuracy: 1.0000 - val_loss: 0.2664 - val_accuracy: 1.0000
# Epoch 4/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.6046 - accuracy: 1.0000 - val_loss: 0.2471 - val_accuracy: 1.0000
# Epoch 5/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.5628 - accuracy: 1.0000 - val_loss: 0.2298 - val_accuracy: 1.0000
# Epoch 6/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.5231 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 1.0000
# Epoch 7/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.4851 - accuracy: 1.0000 - val_loss: 0.1931 - val_accuracy: 1.0000
# Epoch 8/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.4488 - accuracy: 1.0000 - val_loss: 0.1768 - val_accuracy: 1.0000
# Epoch 9/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.4136 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 1.0000
# Epoch 10/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.3787 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 1.0000
# Epoch 11/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.3436 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 1.0000
# Epoch 12/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.3079 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.2700 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 1.0000
# Epoch 14/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.2296 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.1877 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.1437 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.1026 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0666 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 28s 28s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 27s 27s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000

# %%
plot_history(history_new5)

# %%
model_new5.evaluate(test_ds_new5, return_dict=True)
# Out:
# 24/24 [==============================] - 16s 676ms/step - loss: 7.3334e-04 - accuracy: 1.0000
# {'loss': 0.0007333431858569384, 'accuracy': 1.0}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test5/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new5, model_new5)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new5, model_new5)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 24/24 [==============================] - 16s 670ms/step

# %%
precision5, recall5 = calculate_classification_metrics(actual, predicted, labels) # Test dataset

# %%
precision5
# Out:
# {'IntCleaner': 1.0}

# %%
recall5
# Out:
# {'IntCleaner': 1.0}

# %% [markdown]
# # Background and Interactions(jolt + chase + TS + int)

# %% [markdown]
# **2 classes:**
# + Background
# + Intclient + intcleaner + ts + jolt + chase
#
# + learning_rate = 0.001
#
# Path: *Sep_Clips_Test3*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new3_1 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new3_1 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new3_1 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test3/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new3_1 = train_ds_new3_1.batch(batch_size)
val_ds_new3_1 = val_ds_new3_1.batch(batch_size)
test_ds_new3_1 = test_ds_new3_1.batch(batch_size)

# %%
model_new3_1 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new3_1))
model_new3_1.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new3_1, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new3_1.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.001), 
              metrics = ['accuracy'])

# %%
history_new3_1 = model_new3_1.fit(x = train_ds_new3_1, epochs = 50, validation_data = val_ds_new3_1)
# Out:
# Epoch 1/50
# 117/117 [==============================] - 236s 2s/step - loss: 0.6135 - accuracy: 0.6410 - val_loss: 0.5735 - val_accuracy: 0.6591
# Epoch 2/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.
50
# 117/117 [==============================] - 235s 2s/step - loss: 0.5205 - accuracy: 0.6068 - val_loss: 0.4494 - val_accuracy: 0.6364
# Epoch 33/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5219 - accuracy: 0.6410 - val_loss: 0.4609 - val_accuracy: 0.6818
# Epoch 34/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5241 - accuracy: 0.6496 - val_loss: 0.4559 - val_accuracy: 0.6591
# Epoch 35/50
# 117/117 [==============================] - 237s 2s/step - loss: 0.5080 - accuracy: 0.6752 - val_loss: 0.4511 - val_accuracy: 0.7045
# Epoch 36/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.6290 - accuracy: 0.6154 - val_loss: 0.6323 - val_accuracy: 0.6591
# Epoch 37/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6918 - accuracy: 0.5812 - val_loss: 0.6213 - val_accuracy: 0.6591
# Epoch 38/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.6447 - accuracy: 0.6410 - val_loss: 0.6096 - val_accuracy: 0.6591
# Epoch 39/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5759 - accuracy: 0.6410 - val_loss: 0.7527 - val_accuracy: 0.6591
# Epoch 40/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6601 - accuracy: 0.6410 - val_loss: 0.6087 - val_accuracy: 0.6591
# Epoch 41/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6034 - accuracy: 0.6325 - val_loss: 0.5663 - val_accuracy: 0.5909
# Epoch 42/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.9598 - accuracy: 0.6154 - val_loss: 1.8622 - val_accuracy: 0.2955
# Epoch 43/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5755 - accuracy: 0.5983 - val_loss: 0.4680 - val_accuracy: 0.5682
# Epoch 44/50
# 117/117 [==============================] - 237s 2s/step - loss: 0.5305 - accuracy: 0.6068 - val_loss: 0.4988 - val_accuracy: 0.6591
# Epoch 45/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5252 - accuracy: 0.6410 - val_loss: 0.4527 - val_accuracy: 0.5909
# Epoch 46/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5213 - accuracy: 0.5983 - val_loss: 0.4525 - val_accuracy: 0.5909
# Epoch 47/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5162 - accuracy: 0.6154 - val_loss: 0.4690 - val_accuracy: 0.6591
# Epoch 48/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.5133 - accuracy: 0.6496 - val_loss: 0.6701 - val_accuracy: 0.6591
# Epoch 49/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6557 - accuracy: 0.6581 - val_loss: 0.5919 - val_accuracy: 0.6591
# Epoch 50/50
# 117/117 [==============================] - 233s 2s/step - loss: 0.5973 - accuracy: 0.6239 - val_loss: 0.5807 - val_accuracy: 0.6591

# %%
plot_history(history_new3_1)

# %%
model_new3_1.evaluate(test_ds_new3_1, return_dict=True)
# Out:
# 38/38 [==============================] - 35s 909ms/step - loss: 0.5201 - accuracy: 0.6316
# {'loss': 0.5201451182365417, 'accuracy': 0.6315789222717285}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new3_1, model_new3_1)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 125s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new3_1, model_new3_1)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 35s 912ms/step

# %%
precision3_1, recall3_1 = calculate_classification_metrics(actual, predicted, labels) # Test dataset
# Out:
# C:\Users\BEE Team\AppData\Local\Temp\ipykernel_5988\3092751621.py:25: RuntimeWarning: invalid value encountered in long_scalars
#   precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision

# %%
precision3_1
# Out:
# {'IntCleaner': 0.631578947368421, 'background': nan}

# %%
recall3_1
# Out:
# {'IntCleaner': 1.0, 'background': 0.0}

# %% [markdown]
# # Background and Interactions(jolt + chase + TS + int)

# %% [markdown]
# **2 classes:**
# + Background
# + Intclient + intcleaner + ts + jolt + chase
#
# + learning_rate = 0.01
#
# Path: *Sep_Clips_Test3*

# %%
n_frames = 10
batch_size = 1

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

# %%
# Create the training set
train_ds_new3_2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True),
                                          output_signature = output_signature)
# Create the validation set
val_ds_new3_2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/val'), n_frames),
                                        output_signature = output_signature)
# Create the test set
test_ds_new3_2 = tf.data.Dataset.from_generator(FrameGenerator(Path('Summarys_labels/Sep_Clips_test3/test'), n_frames),
                                         output_signature = output_signature)

# %%
# Batch the data
train_ds_new3_2 = train_ds_new3_2.batch(batch_size)
val_ds_new3_2 = val_ds_new3_2.batch(batch_size)
test_ds_new3_2 = test_ds_new3_2.batch(batch_size)

# %%
model_new3_2 = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds_new3_2))
model_new3_2.build(frames)

# %%
# Visualize the model
keras.utils.plot_model(model_new3_2, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_new3_2.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.01), 
              metrics = ['accuracy'])

# %%
history_new3_2 = model_new3_2.fit(x = train_ds_new3_2, epochs = 50, validation_data = val_ds_new3_1)
# Out:
# Epoch 1/50
# 117/117 [==============================] - 236s 2s/step - loss: 0.8099 - accuracy: 0.5726 - val_loss: 0.6134 - val_accuracy: 0.6591
# Epoch 2/50
# 117/117 [==============================] - 234s 2s/step - loss: 1.1319 - accuracy: 0.5214 - val_loss: 2.3985 - val_accuracy: 0.3409
# Epoch 3/50
# 117/117 [==============================] - 235s 2s/step - loss: 1.1255 - accuracy: 0.5299 - val_loss: 0.7034 - val_accuracy: 0.6591
# Epoch 4/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.7005 - accuracy: 0.5812 - val_loss: 0.6422 - val_accuracy: 0.6591
# Epoch 5/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.6637 - accuracy: 0.6410 - val_loss: 0.6568 - val_accuracy: 0.6591
# Epoch 6/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.6694 - accuracy: 0.6410 - val_loss: 0.6417 - val_accuracy: 0.6591
# Epoch 7/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6577 - accuracy: 0.6410 - val_loss: 0.6503 - val_accuracy: 0.6591
# Epoch 8/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6725 - accuracy: 0.6410 - val_loss: 0.6416 - val_accuracy: 0.6591
# Epoch 9/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6704 - accuracy: 0.6410 - val_loss: 0.6554 - val_accuracy: 0.6591
# Epoch 10/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6848 - accuracy: 0.6154 - val_loss: 0.6417 - val_accuracy: 0.6591
# Epoch 11/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6637 - accuracy: 0.6496 - val_loss: 0.6429 - val_accuracy: 0.6591
# Epoch 12/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6770 - accuracy: 0.6154 - val_loss: 0.7819 - val_accuracy: 0.3409
# Epoch 13/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6818 - accuracy: 0.6325 - val_loss: 0.6420 - val_accuracy: 0.6591
# Epoch 14/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6710 - accuracy: 0.6410 - val_loss: 0.6417 - val_accuracy: 0.6591
# Epoch 15/50
# 117/117 [==============================] - 243s 2s/step - loss: 0.6553 - accuracy: 0.6410 - val_loss: 0.6796 - val_accuracy: 0.6591
# Epoch 16/50
# 117/117 [==============================] - 255s 2s/step - loss: 0.6895 - accuracy: 0.6154 - val_loss: 0.6467 - val_accuracy: 0.6591
# Epoch 17/50
# 117/117 [==============================] - 237s 2s/step - loss: 0.6869 - accuracy: 0.6154 - val_loss: 0.6481 - val_accuracy: 0.6591
# Epoch 18/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.6650 - accuracy: 0.6410 - val_loss: 0.6545 - val_accuracy: 0.6591
# Epoch 19/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6669 - accuracy: 0.6410 - val_loss: 0.6426 - val_accuracy: 0.6591
# Epoch 20/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.6711 - accuracy: 0.6410 - val_loss: 0.6420 - val_accuracy: 0.6591
# Epoch 21/50
# 117/117 [==============================] - 235s 2s/step - loss: 0.6686 - accuracy: 0.6410 - val_loss: 0.6438 - val_accuracy: 0.6591
# Epoch 22/50
# 117/117 [==============================] - 234s 2s/step - loss: 0.
return_dict=True)
# Out:
# 38/38 [==============================] - 35s 908ms/step - loss: 0.6583 - accuracy: 0.6316
# {'loss': 0.6583268642425537, 'accuracy': 0.6315789222717285}

# %%
fg = FrameGenerator(Path('Summarys_labels/Sep_Clips_Test3/train'), n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# %%
actual, predicted = get_actual_predicted_labels(train_ds_new3_2, model_new3_2)
plot_confusion_matrix(actual, predicted, labels, 'training')
# Out:
# 117/117 [==============================] - 125s 1s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds_new3_2, model_new3_2)
plot_confusion_matrix(actual, predicted, labels, 'test')
# Out:
# 38/38 [==============================] - 35s 908ms/step

# %%
precision3_2, recall3_2 = calculate_classification_metrics(actual, predicted, labels) # Test dataset
# Out:
# C:\Users\BEE Team\AppData\Local\Temp\ipykernel_5988\3092751621.py:25: RuntimeWarning: invalid value encountered in long_scalars
#   precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision

# %%
precision3_2
# Out:
# {'IntCleaner': 0.631578947368421, 'background': nan}

# %%
recall3_2
# Out:
# {'IntCleaner': 1.0, 'background': 0.0}

# %% [markdown]
# # Saving in picke file

# %%
import pickle

# %% [markdown]
# ## Saving 5 Background and Interactions(jolt + chase + TS + int)

# %%
# Save variables and models to a single pickle file
data = {
    'model_new3': model_new3,
    'history_new3': history_new3
}

with open('Video_Classification-tut-organized-Copy2_5th.pkl', 'wb') as f:
    pickle.dump(data, f)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\add
# ......vars
# ...layers\add_1
# ......vars
# ...layers\add_2
# ......vars
# ...layers\add_3
# ......vars
# ...layers\batch_normalization
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\conv2_plus1d
# ......vars
# ...layers\conv2_plus1d\seq
# ......vars
# ...layers\conv2_plus1d\seq\layers\conv3d
# ......vars
# .........0
# .........1
# ...layers\conv2_plus1d\seq\layers\conv3d_1
# ......vars
# .........0
# .........1
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\flatten
# ......vars
# ...layers\global_average_pooling3d
# ......vars
# ...layers\input_layer
# ......vars
# ...layers\project
# ......vars
# ...layers\project\seq
# ......vars
# ...layers\project\seq\layers\dense
# ......vars
# .........0
# .........1
# ...layers\project\seq\layers\layer_normalization
# ......vars
# .........0
# .........1
# ...layers\project_1
# ......vars
# ...layers\project_1\seq
# ......vars
# ...layers\project_1\seq\layers\dense
# ......vars
# .........0
# .........1
# ...layers\project_1\seq\layers\layer_normalization
# ......vars
# .........0
# .........1
# ...layers\project_2
# ......vars
# ...layers\project_2\seq
# ......vars
# ...layers\project_2\seq\layers\dense
# ......vars
# .........0
# .........1
# ...layers\project_2\seq\layers\layer_normalization
# ......vars
# .........0
# .........1
# ...layers\re_lu
# ......vars
# ...layers\residual_main
# ......vars
# ...layers\residual_main\seq
# ......vars
# ...layers\residual_main\seq\layers\conv2_plus1d
# ......vars
# ...layers\residual_main\seq\layers\conv2_plus1d\seq
# ......vars
# ...layers\residual_main\seq\layers\conv2_plus1d\seq\layers\conv3d
# ......vars
# .........0
# .........1
# ...layers\residual_main\seq\layers\conv2_plus1d\seq\layers\conv3d_1
# ......vars
# .........0
# .........1
# ...layers\residual_main\seq\layers\conv2_plus1d_1
# ......vars
# ...layers\residual_main\seq\layers\conv2_plus1d_1\seq
# ......vars
# ...layers\residual_main\seq\layers\conv2_plus1d_1\seq\layers\conv3d
# ......vars
# .........0
# .........1
# ...layers\residual_main\seq\layers\conv2_plus1d_1\seq\layers\conv3d_1
# ......vars
# .........0
# .........1
# ...layers\residual_main\seq\layers\layer_normalization
# ......vars
# .........0
# .........1
# ...layers\residual_main\seq\layers\layer_normalization_1
# ......vars
# .........0
# .........1
# ...layers\residual_main\seq\layers\re_lu
# ......vars
# ...layers\residual_main_1
# ......vars
# ...layers\residual_main_1\seq
# ......vars
# ...layers\residual_main_1\seq\layers\conv2_plus1d
# ......vars
# ...layers\residual_main_1\seq\layers\conv2_plus1d\seq
# ......vars
# ...layers\residual_main_1\seq\layers\conv2_plus1d\seq\layers\conv3d
# ......vars
# .........0
# .........1
# ...layers\residual_main_1\seq\layers\conv2_plus1d\seq\layers\conv3d_1
# ......vars
# .........0
# .........1
# ...layers\residual_main_1\seq\layers\conv2_plus1d_1
# ......vars
# ...layers\residual_main_1\seq\layers\conv2_plus1d_1\seq
# ......vars
# ...layers\residual_main_1\seq\layers\conv2_plus1d_1\seq\layers\conv3d
# ......vars
# .........0
# .........1
# ...layers\residual_main_1\seq\layers\conv2_plus1d_1\seq\layers\conv3d_1
# ......vars
# .........0
# .........1
# ...layers\residual_main_1\seq\layers\layer_normalization
# ......vars
# .........0
# .........1
# ...layers\residual_main_1\seq\layers\layer_normalization_1
# ......vars
# .........0
# .........1
# ...layers\residual_main_1\seq\layers\re_lu
# ......vars
# ...layers\residual_main_2
# ......vars
# ...layers\residual_main_2\seq
# ......vars
# ...layers\residual_main_2\seq\layers\conv2_plus1d
# ......vars
# ...layers\residual_main_2\seq\layers\conv2_plus1d\seq
# ......vars
# ...layers\residual_main_2\seq\layers\conv2_plus1d\seq\layers\conv3d
# ......vars
# .........0
# .........1
# ...layers\residual_main_2\seq\layers\conv2_plus1d\seq\layers\conv3d_1
# ......vars
# .........0
# .........1
# ...layers\residual_main_2\seq\layers\conv2_plus1d_1
# ......vars
# ...layers\residual_main_2\seq\layers\conv2_plus1d_1\seq
# ......vars
# ...layers\residual_main_2\seq\layers\conv2_plus1d_1\seq\layers\conv3d
# ......vars
# .........0
# .........1
# ...layers\residual_main_2\seq\layers\conv2_plus1d_1\seq\layers\conv3d_1
# ......vars
# .........0
# .........1
# ...layers\residual_main_2\seq\layers\layer_normalization
# ......vars
# .........0
# .........1
# ...layers\residual_main_2\seq\layers\layer_normalization_1
# ......vars
# .........0
# .........1
# ...layers\residual_main_2\seq\layers\re_lu
# ......vars
# ...layers\residual_main_3
# ......vars
# ...layers\residual_main_3\seq
# ......vars
# ...layers\residual_main_3\seq\layers\conv2_plus1d
# ......vars
# ...layers\residual_main_3\seq\layers\conv2_plus1d\seq
# ......vars
# ...layers\residual_main_3\seq\layers\conv2_plus1d\seq\layers\conv3d
# ......vars
# .........0
# .........1
# ...layers\residual_main_3\seq\layers\conv2_plus1d\seq\layers\conv3d_1
# ......vars
# .........0
# .........1
# ...layers\residual_main_3\seq\layers\conv2_plus1d_1
# ......vars
# ...layers\residual_main_3\seq\layers\conv2_plus1d_1\seq
# ......vars
# ...layers\residual_main_3\seq\layers\conv2_plus1d_1\seq\layers\conv3d
# ......vars
# .........0
# .........1
# ...layers\residual_main_3\seq\layers\conv2_plus1d_1\seq\layers\conv3d_1
# ......vars
# .........0
# .........1
# ...layers\residual_main_3\seq\layers\layer_normalization
# ......vars
# .........0
# .........1
# ...layers\residual_main_3\seq\layers\layer_normalization_1
# ......vars
# .........0
# .........1
# ...layers\residual_main_3\seq\layers\re_lu
# ......vars
# ...layers\resize_video
# ......vars
# ...layers\resize_video\resizing_layer
# ......vars
# ...layers\resize_video_1
# ......vars
# ...layers\resize_video_1\resizing_layer
# ......vars
# ...layers\resize_video_2
# ......vars
# ...layers\resize_video_2\resizing_layer
# ......vars
# ...layers\resize_video_3
# ......vars
# ...layers\resize_video_3\resizing_layer
# ......vars
# ...metrics\mean
# ......vars
# .........0
# .........1
# ...metrics\mean_metric_wrapper
# ......vars
# .........0
# .........1
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-05-18 00:37:11     11105124
# metadata.json                                  2023-05-18 00:37:11           64
# variables.h5                                   2023-05-18 00:37:11      1972560

# %%
# # Load the pickled data
# with open('Video_Classification-tut-organized-Copy2_5th.pk', 'rb') as f:
#     data = pickle.load(f)

# model_new3_restored = data['model_new3']
# history_new3_restored = data['history_new3']

# %%
model_new3.evaluate(test_ds_new3, return_dict=True)
# Out:
# 38/38 [==============================] - 35s 897ms/step - loss: 0.6583 - accuracy: 0.6316
# {'loss': 0.6583268642425537, 'accuracy': 0.6315789222717285}
